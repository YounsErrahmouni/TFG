# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv('2018_accidents_causa_conductor_gu_bcn_.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10835 entries, 0 to 10834
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Numero_expedient            10835 non-null  object
#  1   Codi_districte              10835 non-null  int64
#  2   Nom_districte               10835 non-null  object
#  3   Codi_barri                  10835 non-null  int64
#  4   Nom_barri                   10835 non-null  object
#  5   Codi_carrer                 10835 non-null  int64
#  6   Nom_carrer                  10835 non-null  object
#  7   Num_postal                  10835 non-null  object
#  8   Descripcio_dia_setmana      10835 non-null  object
#  9   NK_Any                      10835 non-null  int64
#  10  Mes_any                     10835 non-null  int64
#  11  Nom_mes                     10835 non-null  object
#  12  Dia_mes                     10835 non-null  int64
#  13  Hora_dia                    10835 non-null  int64
#  14  Descripcio_torn             10835 non-null  object
#  15  Descripcio_causa_conductor  10835 non-null  object
#  16  Coordenada_UTM_X_ED50       10835 non-null  float64
#  17  Coordenada_UTM_Y_ED50       10835 non-null  float64
#  18  Longitud                    10835 non-null  float64
#  19  Latitud                     10835 non-null  float64
# dtypes: float64(4), int64(7), object(9)
# memory usage: 1.7+ MB
# There are this number of expedients 10835
# 9920
#       Numero_expedient  Codi_districte Nom_districte  Codi_barri   Nom_barri  \
# 0      2018S009297                  -1    Desconegut          -1  Desconegut
# 1      2018S006070                  -1    Desconegut          -1  Desconegut
# 2      2018S002030                  -1    Desconegut          -1  Desconegut
# 3      2018S005592                  -1    Desconegut          -1  Desconegut
# 4      2018S002762                  -1    Desconegut          -1  Desconegut
# ...                ...             ...           ...         ...         ...
# 10830  2018S007403                   8    Nou Barris          45       Porta
# 10831  2018S006695                   8    Nou Barris          45       Porta
# 10832  2018S004428                   8    Nou Barris          45       Porta
# 10833  2018S009470                   8    Nou Barris          45       Porta
# 10834  2018S006448                   8    Nou Barris          45       Porta
#
#        Codi_carrer                                         Nom_carrer  \
# 0               -1  Pare Pérez del Pulgar                         ...
# 1               -1  Joan XXIII                                    ...
# 2               -1  Corts Catalanes                               ...
# 3               -1  Martin Luther King                            ...
# 4               -1  Francesc Ferrer i Guàrdia                     ...
# ...            ...                                                ...
# 10830       256401                                    Pintor Alsamora
# 10831       256401                                    Pintor Alsamora
# 10832       256401                                    Pintor Alsamora
# 10833       700021                                         Andreu Nin
# 10834       282650                                     Rio de Janeiro
#
#       Num_postal  Descripcio_dia_setmana  NK_Any  Mes_any   Nom_mes  Dia_mes  \
# 0      106                       Dimarts    2018       12  Desembre        4
# 1      2-16                      Dilluns    2018        8     Agost        6
# 2      900                       Dimarts    2018        3      Març       13
# 3      65                         Dijous    2018        7    Juliol       19
# 4      16-36                    Dimecres    2018        4     Abril       11
# ...           ...                    ...     ...      ...       ...      ...
# 10830   0001 0001                Dimarts    2018       10   Octubre        2
# 10831   0001 0001                Dimarts    2018        9  Setembre        4
# 10832   0004 0004              Divendres    2018        6      Juny        8
# 10833   0022 0052               Dimecres    2018       12  Desembre       12
# 10834   0001 0001              Divendres    2018        8     Agost       24
#
#        Hora_dia                        Descripcio_torn  \
# 0            18         Manca d'atenció a la conducció
# 1            12                         No determinada
# 2            14                No respectar distàncies
# 3            13                       Desobeir semàfor
# 4            11                         No determinada
# ...         ...                                    ...
# 10830         9                                 Altres
# 10831        20                             Desconegut
# 10832        15                                 Altres
# 10833         9  Manca precaució efectuar marxa enrera
# 10834        10         Manca d'atenció a la conducció
#
#       Descripcio_causa_conductor  Coordenada_UTM_X_ED50  \
# 0                          Tarda              432687.83
# 1                           Matí              426640.90
# 2                          Tarda              432587.59
# 3                           Matí              432765.75
# 4                           Matí              428901.74
# ...                          ...                    ...
# 10830                       Matí              431890.58
# 10831                      Tarda              431890.58
# 10832                      Tarda              431418.93
# 10833                       Matí              431666.57
# 10834                       Matí              431790.37
#
#        Coordenada_UTM_Y_ED50  Longitud    Latitud
# 0                 4589691.16  2.192952  41.454139
# 1                 4581697.55  2.121531  41.381614
# 2                 4584475.05  2.192334  41.407151
# 3                 4588432.80  2.194025  41.442812
# 4                 4580348.80  2.148725  41.369670
# ...                      ...       ...        ...
# 10830             4587477.65  2.183658  41.434136
# 10831             4587477.65  2.183658  41.434136
# 10832             4587654.36  2.177993  41.435687
# 10833             4587354.82  2.180991  41.433010
# 10834             4587315.77  2.182477  41.432669
#
# [10835 rows x 20 columns]

# %%
data_set = pd.read_csv('2019_accidents_causa_conductor_gu_bcn_.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11025 entries, 0 to 11024
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Numero_expedient            11025 non-null  object
#  1   Codi_districte              11025 non-null  int64
#  2   Nom_districte               11025 non-null  object
#  3   Codi_barri                  11025 non-null  int64
#  4   Nom_barri                   11025 non-null  object
#  5   Codi_carrer                 11025 non-null  int64
#  6   Nom_carrer                  11025 non-null  object
#  7   Num_postal                  11018 non-null  object
#  8   Descripcio_dia_setmana      11025 non-null  object
#  9   NK_Any                      11025 non-null  int64
#  10  Mes_any                     11025 non-null  int64
#  11  Nom_mes                     11025 non-null  object
#  12  Dia_mes                     11025 non-null  int64
#  13  Hora_dia                    11025 non-null  int64
#  14  Descripcio_torn             11025 non-null  object
#  15  Descripcio_causa_conductor  11025 non-null  object
#  16  Coordenada_UTM_X_ED50       11025 non-null  float64
#  17  Coordenada_UTM_Y_ED50       11025 non-null  float64
#  18  Longitud                    11025 non-null  float64
#  19  Latitud                     11025 non-null  float64
# dtypes: float64(4), int64(7), object(9)
# memory usage: 1.7+ MB
# There are this number of expedients 11025
# 10015
#       Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0      2019S009428                  -1    Desconegut          -1
# 1      2019S003731                  -1    Desconegut          -1
# 2      2019S004771                  -1    Desconegut          -1
# 3      2019S005061                  -1    Desconegut          -1
# 4      2019S002767                  -1    Desconegut          -1
# ...                ...             ...           ...         ...
# 11020  2019S006440                   8    Nou Barris          45
# 11021  2019S003316                   8    Nou Barris          44
# 11022  2019S006350                   8    Nou Barris          45
# 11023  2019S002833                   8    Nou Barris          45
# 11024  2019S003869                   8    Nou Barris          45
#
#                            Nom_barri  Codi_carrer  \
# 0                         Desconegut           -1
# 1                         Desconegut           -1
# 2                         Desconegut           -1
# 3                         Desconegut           -1
# 4                         Desconegut           -1
# ...                              ...          ...
# 11020                          Porta       282650
# 11021  Vilapicina i la Torre Llobeta       119003
# 11022                          Porta       351901
# 11023                          Porta       190100
# 11024                          Porta       282650
#
#                                               Nom_carrer Num_postal   \
# 0      Santa Coloma                                  ...  55-71
# 1      Vallvidrera a les Planes / Vesc               ...         NaN
# 2      Josep Tarradellas / Viriat                    ...         NaN
# 3      Lepant / Sant Pere                            ...         NaN
# 4      Joan XXIII / Arístides Maillol                ...         NaN
# ...                                                  ...         ...
# 11020                                     Rio de Janeiro   0055 0055
# 11021                                       Fabra i Puig   0181 0181
# 11022                                          Valldaura   0276 0278
# 11023                                           Maladeta   0027 0029
# 11024                                     Rio de Janeiro   0003 0003
#
#       Descripcio_dia_setmana  NK_Any  Mes_any   Nom_mes  Dia_mes  Hora_dia  \
# 0                  Divendres    2019       12  Desembre        6        16
# 1                   Dimecres    2019        5      Maig       15         9
# 2                    Dimarts    2019        6      Juny       18        17
# 3                  Divendres    2019        6      Juny       28         5
# 4                    Dilluns    2019        4     Abril        8        18
# ...                      ...     ...      ...       ...      ...       ...
# 11020                 Dijous    2019        8     Agost       15        16
# 11021                Dimarts    2019        4     Abril       30        17
# 11022               Dissabte    2019        8     Agost       10         8
# 11023               Dimecres    2019        4     Abril       10        12
# 11024               Diumenge    2019        5      Maig       19        19
#
#                                Descripcio_torn Descripcio_causa_conductor  \
# 0                                   Desconegut                      Tarda
# 1                Gir indegut o sense precaució                       Matí
# 2      Manca precaució incorporació circulació                      Tarda
# 3                Gir indegut o sense precaució                        Nit
# 4                                       Altres                      Tarda
# ...                                        ...                        ...
# 11020                  Desobeir altres senyals                      Tarda
# 11021                                   Altres                      Tarda
# 11022           Manca d'atenció a la conducció                       Matí
# 11023             No respectat pas de vianants                       Matí
# 11024                               Desconegut                      Tarda
#
#        Coordenada_UTM_X_ED50  Coordenada_UTM_Y_ED50  Longitud    Latitud
# 0                  432727.25             4588841.54  2.193519  41.446490
# 1                  424364.44             4586356.76  2.093726  41.423366
# 2                  428395.22             4581569.25  2.142525  41.380617
# 3                  430512.83             4584971.91  2.167457  41.411449
# 4                  426410.27             4581606.20  2.118784  41.380770
# ...                      ...                    ...       ...        ...
# 11020              431624.03             4587735.74  2.180438  41.436437
# 11021              431360.13             4587054.30  2.177357  41.430277
# 11022              431735.72             4588048.32  2.181740  41.439262
# 11023              431269.09             4587279.78  2.176242  41.432300
# 11024              431762.38             4587093.40  2.182167  41.430664
#
# [11025 rows x 20 columns]

# %%
data_set = pd.read_csv('2020_accidents_causa_conductor_gu_bcn_.csv',sep = ",")
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7595 entries, 0 to 7594
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Numero_expedient            7595 non-null   object
#  1   Codi_districte              7595 non-null   int64
#  2   Nom_districte               7595 non-null   object
#  3   Codi_barri                  7595 non-null   int64
#  4   Nom_barri                   7595 non-null   object
#  5   Codi_carrer                 7595 non-null   int64
#  6   Nom_carrer                  7595 non-null   object
#  7   Num_postal                  7589 non-null   object
#  8   Descripcio_dia_setmana      7595 non-null   object
#  9   NK_Any                      7595 non-null   int64
#  10  Mes_any                     7595 non-null   int64
#  11  Nom_mes                     7595 non-null   object
#  12  Dia_mes                     7595 non-null   int64
#  13  Hora_dia                    7595 non-null   int64
#  14  Descripcio_torn             7595 non-null   object
#  15  Descripcio_causa_conductor  7595 non-null   object
#  16  Coordenada_UTM_X_ED50       7595 non-null   float64
#  17  Coordenada_UTM_Y_ED50       7595 non-null   float64
#  18  Longitud                    7595 non-null   float64
#  19  Latitud                     7595 non-null   float64
# dtypes: float64(4), int64(7), object(9)
# memory usage: 1.2+ MB
# There are this number of expedients 7595
# 6261
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0     2020S006254                  -1    Desconegut          -1
# 1     2020S001630                  -1    Desconegut          -1
# 2     2020S001281                  -1    Desconegut          -1
# 3     2020S001227                  -1    Desconegut          -1
# 4     2020S002367                  -1    Desconegut          -1
# ...               ...             ...           ...         ...
# 7590  2020S000242                   8    Nou Barris          44
# 7591  2020S001025                   8    Nou Barris          46
# 7592  2020S000035                   8    Nou Barris          45
# 7593  2020S003737                   8    Nou Barris          45
# 7594  2020S000309                   8    Nou Barris          45
#
#                           Nom_barri  Codi_carrer  \
# 0                        Desconegut           -1
# 1                        Desconegut           -1
# 2                        Desconegut           -1
# 3                        Desconegut           -1
# 4                        Desconegut           -1
# ...                             ...          ...
# 7590  Vilapicina i la Torre Llobeta       111704
# 7591            el Turó de la Peira        54000
# 7592                          Porta       289852
# 7593                          Porta       256401
# 7594                          Porta       113404
#
#                                              Nom_carrer Num_postal   \
# 0     Corts / Arístides Maillol                     ...         NaN
# 1     Corts Catalanes / Castillejos                 ...         NaN
# 2     Corts Catalanes                               ...  871
# 3     A Zona Franca / Número 3 Zona Franca          ...         NaN
# 4     Molins de Rei                                 ...  K60
# ...                                                 ...         ...
# 7590                                            Escòcia   0086 0086
# 7591                                               Cadí   0022 0022
# 7592                                  Rosselló i Porcel   0002 0002
# 7593                                    Pintor Alsamora   0001 0001
# 7594                                   Escultor Ordóñez   0197 0199
#
#      Descripcio_dia_setmana  NK_Any  Mes_any   Nom_mes  Dia_mes  Hora_dia  \
# 0                  Dimecres    2020       12  Desembre       30         9
# 1                  Dimecres    2020        3      Març        4        14
# 2                  Dimecres    2020        2    Febrer       19        22
# 3                   Dimarts    2020        2    Febrer       18        10
# 4                  Dissabte    2020        5      Maig       30        12
# ...                     ...     ...      ...       ...      ...       ...
# 7590               Diumenge    2020        1     Gener       12        20
# 7591                Dilluns    2020        2    Febrer       10         9
# 7592              Divendres    2020        1     Gener        3        12
# 7593               Dimecres    2020        8     Agost       19        19
# 7594               Dimecres    2020        1     Gener       15        11
#
#                             Descripcio_torn Descripcio_causa_conductor  \
# 0     Manca precaució efectuar marxa enrera                       Matí
# 1                   No respectar distàncies                      Tarda
# 2                          Desobeir semàfor                        Nit
# 3            Manca d'atenció a la conducció                       Matí
# 4                                    Altres                       Matí
# ...                                     ...                        ...
# 7590                                 Altres                      Tarda
# 7591  Manca precaució efectuar marxa enrera                       Matí
# 7592                                 Altres                       Matí
# 7593                         No determinada                      Tarda
# 7594                Desobeir altres senyals                       Matí
#
#       Coordenada_UTM_X_ED50  Coordenada_UTM_Y_ED50  Longitud    Latitud
# 0                 426626.85             4581292.09  2.122513  41.379807
# 1                 431937.47             4583875.38  2.185727  41.403541
# 2                 432561.42             4584522.58  2.193119  41.409423
# 3                 428020.43             4576283.26  2.139771  41.334820
# 4                 422891.03             4584730.23  2.077403  41.410423
# ...                     ...                    ...       ...        ...
# 7590              431514.05             4586864.21  2.180323  41.430424
# 7591              430607.68             4587157.78  2.169443  41.432991
# 7592              431855.93             4587772.72  2.184312  41.438636
# 7593              431781.49             4587486.66  2.183454  41.436053
# 7594              431415.39             4587875.93  2.179028  41.439528
#
# [7595 rows x 20 columns]

# %%
data_set = pd.read_csv('2021_accidents_causa_conductor_gu_bcn_.csv',sep = ",")
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8979 entries, 0 to 8978
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Numero_expedient          8979 non-null   object
#  1   Codi_districte            8979 non-null   int64
#  2   Nom_districte             8979 non-null   object
#  3   Codi_barri                8979 non-null   int64
#  4   Nom_barri                 8979 non-null   object
#  5   Codi_carrer               8979 non-null   int64
#  6   Nom_carrer                8979 non-null   object
#  7   Num_postal                8979 non-null   object
#  8   Descripcio_dia_setmana    8979 non-null   object
#  9   NK_Any                    8979 non-null   int64
#  10  Mes_any                   8979 non-null   int64
#  11  Nom_mes                   8979 non-null   object
#  12  Dia_mes                   8979 non-null   int64
#  13  Hora_dia                  8979 non-null   int64
#  14  Descripcio_causa_mediata  8979 non-null   object
#  15  Descripcio_torn           8979 non-null   object
#  16  Coordenada_UTM_X_ED50     8979 non-null   float64
#  17  Coordenada_UTM_Y_ED50     8979 non-null   float64
#  18  Longitud                  8949 non-null   float64
#  19  Latitud                   8949 non-null   float64
# dtypes: float64(4), int64(7), object(9)
# memory usage: 1.4+ MB
# There are this number of expedients 8979
# 7652
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0     2021S002333                  -1    Desconegut          -1
# 1     2021S004053                  10    Sant Martí          64
# 2     2021S004679                  10    Sant Martí          64
# 3     2021S004271                  10    Sant Martí          64
# 4     2021S005246                  10    Sant Martí          64
# ...               ...             ...           ...         ...
# 8974  2021S000531                   8    Nou Barris          45
# 8975  2021S004840                   8    Nou Barris          44
# 8976  2021S004824                   8    Nou Barris          45
# 8977  2021S005061                   8    Nou Barris          44
# 8978  2021S004898                   8    Nou Barris          45
#
#                           Nom_barri  Codi_carrer  \
# 0                        Desconegut           -1
# 1        el Camp de l'Arpa del Clot       209900
# 2        el Camp de l'Arpa del Clot       346402
# 3        el Camp de l'Arpa del Clot       134801
# 4        el Camp de l'Arpa del Clot       161407
# ...                             ...          ...
# 8974                          Porta       242000
# 8975  Vilapicina i la Torre Llobeta       119003
# 8976                          Porta       256401
# 8977  Vilapicina i la Torre Llobeta       266100
# 8978                          Porta       700021
#
#                                              Nom_carrer Num_postal   \
# 0     Guinardó                                      ...          57
# 1                                             Meridiana   0179 0179
# 2                                              Trinxant   0073 0075
# 3                                                Freser   0218 0218
# 4                                             Indústria   0257 0257
# ...                                                 ...         ...
# 8974                                 Ciutat de Mallorca   0024 0024
# 8975                                       Fabra i Puig   0181 0181
# 8976                                    Pintor Alsamora   0001 0001
# 8977                                   Prat d'en Roquer   0009 0013
# 8978                                         Andreu Nin  0029X0029X
#
#      Descripcio_dia_setmana  NK_Any  Mes_any   Nom_mes  Dia_mes  Hora_dia  \
# 0                  Dimecres    2021        5      Maig        5        15
# 1                   Dilluns    2021        7    Juliol       19        17
# 2                   Dimarts    2021        8     Agost       24        16
# 3                    Dijous    2021        7    Juliol       29        11
# 4                   Dimarts    2021        9  Setembre       21         6
# ...                     ...     ...      ...       ...      ...       ...
# 8974                Dimarts    2021        2    Febrer        2        16
# 8975              Divendres    2021        9  Setembre        3         0
# 8976                 Dijous    2021        9  Setembre        2         8
# 8977                Dilluns    2021        9  Setembre       13        13
# 8978                Dilluns    2021        9  Setembre        6        16
#
#             Descripcio_causa_mediata Descripcio_torn  Coordenada_UTM_X_ED50  \
# 0            No respectar distàncies           Tarda              430550.11
# 1            No respectar distàncies           Tarda              432112.41
# 2       No respectat pas de vianants           Tarda              431951.08
# 3      Gir indegut o sense precaució            Matí              431828.84
# 4                     No determinada            Matí              431553.87
# ...                              ...             ...                    ...
# 8974                Desobeir semàfor           Tarda              431470.52
# 8975         Desobeir altres senyals             Nit              431371.64
# 8976  Manca d'atenció a la conducció            Matí              431781.49
# 8977  Manca d'atenció a la conducció            Matí              431325.36
# 8978                Desobeir semàfor           Tarda              431700.99
#
#       Coordenada_UTM_Y_ED50  Longitud    Latitud
# 0                4585063.91  2.167892  41.412278
# 1                4585138.78  2.186575  41.413086
# 2                4585370.32  2.184619  41.415158
# 3                4585537.12  2.183137  41.416650
# 4                4585250.39  2.179880  41.414044
# ...                     ...       ...        ...
# 8974             4587354.60  2.178644  41.432989
# 8975             4587040.12  2.177496  41.430148
# 8976             4587486.66  2.182351  41.434205
# 8977             4586527.80  2.177001  41.425530
# 8978             4587483.33  2.181388  41.434168
#
# [8979 rows x 20 columns]

# %%
data_set = pd.read_csv('2022_accidents_causa_conductor_gu_bcn_.csv',sep = ",")
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9320 entries, 0 to 9319
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Numero_expedient            9320 non-null   object
#  1   Codi_districte              9320 non-null   int64
#  2   Nom_districte               9320 non-null   object
#  3   Codi_barri                  9320 non-null   int64
#  4   Nom_barri                   9320 non-null   object
#  5   Codi_carrer                 9320 non-null   int64
#  6   Nom_carrer                  9319 non-null   object
#  7   Num_postal                  9319 non-null   object
#  8   Descripcio_dia_setmana      9320 non-null   object
#  9   NK_Any                      9320 non-null   int64
#  10  Mes_any                     9320 non-null   int64
#  11  Nom_mes                     9320 non-null   object
#  12  Dia_mes                     9320 non-null   int64
#  13  Hora_dia                    9320 non-null   int64
#  14  Descripcio_torn             9320 non-null   object
#  15  Descripcio_causa_conductor  9320 non-null   object
#  16  Coordenada_UTM_X_ED50       9320 non-null   float64
#  17  Coordenada_UTM_Y_ED50       9320 non-null   float64
#  18  Longitud                    9320 non-null   float64
#  19  Latitud                     9320 non-null   float64
# dtypes: float64(4), int64(7), object(9)
# memory usage: 1.4+ MB
# There are this number of expedients 9320
# 7989
#      Numero_expedient  Codi_districte Nom_districte  Codi_barri  \
# 0     2022S007861                  -1    Desconegut          -1
# 1     2022S007184                  -1    Desconegut          -1
# 2     2022S001588                  -1    Desconegut          -1
# 3     2022S001502                  -1    Desconegut          -1
# 4     2022S004395                  -1    Desconegut          -1
# ...               ...             ...           ...         ...
# 9315  2022S007322                   9   Sant Andreu          61
# 9316  2022S004058                   8    Nou Barris          46
# 9317  2022S008007                   8    Nou Barris          44
# 9318  2022S007475                   8    Nou Barris          44
# 9319  2022S002249                   8    Nou Barris          45
#
#                           Nom_barri  Codi_carrer  \
# 0                        Desconegut           -1
# 1                        Desconegut           -1
# 2                        Desconegut           -1
# 3                        Desconegut           -1
# 4                        Desconegut           -1
# ...                             ...          ...
# 9315                     la Sagrera       216509
# 9316            el Turó de la Peira       228009
# 9317  Vilapicina i la Torre Llobeta       119003
# 9318  Vilapicina i la Torre Llobeta       119003
# 9319                          Porta       282650
#
#                                              Nom_carrer Num_postal   \
# 0     Jordi Girona                                  ...  18-26
# 1     Ferrocarrils Catalans                         ...  87-89
# 2     Número 3 Zona Franca / E Zona Franca          ...         NaN
# 3     Guipúscoa                                     ...  171
# 4     Espronceda                                    ...  360
# ...                                                 ...         ...
# 9315  Monlau / Martí Molins                         ...   0027 0027
# 9316  Doctor Pi i Molist                            ...   0002 0002
# 9317  Arnau d'Oms                                   ...   0181 0181
# 9318  Arnau d'Oms / Fabra i Puig                    ...   0181 0181
# 9319  Meridiana                                     ...   0001 0001
#
#      Descripcio_dia_setmana  NK_Any  Mes_any   Nom_mes  Dia_mes  Hora_dia  \
# 0                    Dijous    2022       12  Desembre       22        21
# 1                  Dimecres    2022       11  Novembre       23        15
# 2                 Divendres    2022        3      Març       18        14
# 3                 Divendres    2022        3      Març       11        14
# 4                   Dilluns    2022        7    Juliol       18        14
# ...                     ...     ...      ...       ...      ...       ...
# 9315                Dimarts    2022       11  Novembre       29        14
# 9316                Dilluns    2022        7    Juliol        4         9
# 9317               Dissabte    2022       12  Desembre       31        21
# 9318                Dilluns    2022       12  Desembre        5        15
# 9319                Dilluns    2022        4     Abril       18        23
#
#                               Descripcio_torn Descripcio_causa_conductor  \
# 0                     No respectar distàncies                      Tarda
# 1              Manca d'atenció a la conducció                      Tarda
# 2                     No respectar distàncies                      Tarda
# 3              Manca d'atenció a la conducció                      Tarda
# 4                              No determinada                      Tarda
# ...                                       ...                        ...
# 9315  Manca precaució incorporació circulació                      Tarda
# 9316                               Desconegut                       Matí
# 9317           Manca d'atenció a la conducció                      Tarda
# 9318                         Desobeir semàfor                      Tarda
# 9319           Manca d'atenció a la conducció                        Nit
#
#       Coordenada_UTM_X_ED50  Coordenada_UTM_Y_ED50  Longitud    Latitud
# 0                 426095.42             4582377.28  2.114925  41.387686
# 1                 428304.24             4579361.29  2.141698  41.360722
# 2                 427265.97             4576644.81  2.129612  41.336163
# 3                 433835.76             4586344.61  2.207062  41.424093
# 4                 432104.01             4585819.08  2.186398  41.419216
# ...                     ...                    ...       ...        ...
# 9315              432448.51             4586350.96  2.190461  41.424035
# 9316              430923.20             4587579.42  2.172068  41.434970
# 9317              431370.38             4587010.59  2.177485  41.429885
# 9318              431360.13             4587054.30  2.177357  41.430277
# 9319              431791.13             4587315.35  2.182486  41.432665
#
# [9320 rows x 20 columns]
