# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv('2018_accidents_gu_bcn.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)

data_set.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9936 entries, 0 to 9935
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           9936 non-null   object
#  1   Codi_districte             9936 non-null   int64
#  2   Nom_districte              9936 non-null   object
#  3   Codi_barri                 9936 non-null   int64
#  4   Nom_barri                  9936 non-null   object
#  5   Codi_carrer                9936 non-null   int64
#  6   Nom_carrer                 9935 non-null   object
#  7   Num_postal                 5138 non-null   object
#  8   Descripcio_dia_setmana     9936 non-null   object
#  9   Dia_setmana                9936 non-null   object
#  10  Descripcio_tipus_dia       9936 non-null   object
#  11  Any                        9936 non-null   int64
#  12  Mes_any                    9936 non-null   int64
# ...

# %%
data_set = pd.read_csv('2019_accidents_gu_bcn.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)

data_set.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10027 entries, 0 to 10026
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           10027 non-null  object
#  1   Codi_districte             10027 non-null  int64
#  2   Nom_districte              10027 non-null  object
#  3   Codi_barri                 10027 non-null  int64
#  4   Nom_barri                  10027 non-null  object
#  5   Codi_carrer                10027 non-null  int64
#  6   Nom_carrer                 10027 non-null  object
#  7   Num_postal_caption         10027 non-null  object
#  8   Descripcio_dia_setmana     10027 non-null  object
#  9   Dia_setmana                10027 non-null  object
#  10  Descripcio_tipus_dia       10027 non-null  object
#  11  NK_Any                     10027 non-null  int64
#  12  Mes_any                    10027 non-null  int64
# ...

# %%
data_set = pd.read_csv('2020_accidents_gu_bcn.csv',sep = ",")
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)

data_set.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6268 entries, 0 to 6267
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           6268 non-null   object
#  1   Codi_districte             6268 non-null   int64
#  2   Nom_districte              6268 non-null   object
#  3   Codi_barri                 6268 non-null   object
#  4   Nom_barri                  6268 non-null   object
#  5   Codi_carrer                6268 non-null   int64
#  6   Nom_carrer                 6268 non-null   object
#  7   Num_postal_caption         6268 non-null   object
#  8   Descripcio_dia_setmana     6268 non-null   object
#  9   Dia_setmana                6268 non-null   int64
#  10  Descripcio_tipus_dia       6268 non-null   object
#  11  NK_Any                     6268 non-null   int64
#  12  Mes_any                    6268 non-null   int64
# ...

# %%
data_set = pd.read_csv('2021_accidents_gu_bcn.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)

data_set.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7659 entries, 0 to 7658
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           7659 non-null   object
#  1   Codi_districte             7659 non-null   int64
#  2   Nom_districte              7659 non-null   object
#  3   Codi_barri                 7659 non-null   int64
#  4   Nom_barri                  7659 non-null   object
#  5   Codi_carrer                7659 non-null   int64
#  6   Nom_carrer                 7659 non-null   object
#  7   Num_postal_caption         7659 non-null   object
#  8   Descripcio_dia_setmana     7659 non-null   object
#  9   NK_Any                     7659 non-null   int64
#  10  Mes_any                    7659 non-null   int64
#  11  Nom_mes                    7659 non-null   object
#  12  Dia_mes                    7659 non-null   int64
# ...

# %%
data_set = pd.read_csv('2022_accidents_gu_bcn.csv',sep = ",")
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)

data_set.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Numero_expedient           7999 non-null   object
#  1   Codi_districte             7999 non-null   int64
#  2   Nom_districte              7999 non-null   object
#  3   Codi_barri                 7999 non-null   int64
#  4   Nom_barri                  7999 non-null   object
#  5   Codi_carrer                7999 non-null   int64
#  6   Nom_carrer                 7998 non-null   object
#  7   Num_postal_caption         7999 non-null   object
#  8   Descripcio_dia_setmana     7999 non-null   object
#  9   NK_Any                     7999 non-null   int64
#  10  Mes_any                    7999 non-null   int64
#  11  Nom_mes                    7999 non-null   object
#  12  Dia_mes                    7999 non-null   int64
# ...
