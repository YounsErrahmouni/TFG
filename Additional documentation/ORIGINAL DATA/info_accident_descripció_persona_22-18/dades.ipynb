# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv('2018_accidents_persones_gu_bcn_.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)

data_set.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11854 entries, 0 to 11853
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Numero_expedient             11854 non-null  object
#  1   Codi_districte               11854 non-null  int64
#  2   Nom_districte                11854 non-null  object
#  3   Codi_barri                   11854 non-null  int64
#  4   Nom_barri                    11854 non-null  object
#  5   Codi_carrer                  11854 non-null  int64
#  6   Nom_carrer                   11854 non-null  object
#  7   Num_postal                   4607 non-null   object
#  8   Descripcio_dia_setmana       11854 non-null  object
#  9   Dia_setmana                  11854 non-null  object
#  10  Descripcio_tipus_dia         11854 non-null  object
#  11  Any                          11854 non-null  int64
#  12  Mes_ any                     11854 non-null  int64
#  13  Nom_mes                      11854 non-null  object
#  14  Dia_mes                      11854 non-null  int64
#  15  Descripcio_torn              11854 non-null  object
#  16  Hora_dia                     11854 non-null  int64
#  17  Descripcio_causa_vianant     11854 non-null  object
#  18  Desc_Tipus_vehicle_implicat  11854 non-null  object
#  19  Descripcio_sexe              11854 non-null  object
#  20  Edat                         11854 non-null  object
#  21  Descripcio_tipus_persona     11854 non-null  object
#  22  Descripcio_situacio          11854 non-null  object
#  23  Descripcio_victimitzacio     11854 non-null  object
#  24  Coordenada_UTM_X             11854 non-null  float64
#  25  Coordenada_UTM_Y             11854 non-null  float64
#  26  Longitud                     11854 non-null  float64
#  27  Latitud                      11854 non-null  float64
# dtypes: float64(4), int64(7), object(17)
# memory usage: 2.5+ MB
# There are this number of expedients 11854
# 9190
# Numero_expedient                                                 2018S000001
# Codi_districte                                                                 3
# Nom_districte                                                     Sants-Montjuïc
# Codi_barri                                                                    11
# Nom_barri                                                           el Poble-sec
# Codi_carrer                                                               273400
# Nom_carrer                     Paral·lel                                     ...
# Num_postal                                                            117-119
# Descripcio_dia_setmana                                                   Dilluns
# Dia_setmana                                                                   Dl
# Descripcio_tipus_dia                                                     Laboral
# Any                                                                         2018
# Mes_ any                                                                       1
# Nom_mes                                                                    Gener
# Dia_mes                                                                        1
# Descripcio_torn                                                              Nit
# Hora_dia                                                                       3
# Descripcio_causa_vianant                                No és causa del  vianant
# Desc_Tipus_vehicle_implicat                                              Turisme
# Descripcio_sexe                                                             Home
# Edat                                                                          41
# Descripcio_tipus_persona                                               Conductor
# Descripcio_situacio                                                    Presentat
# Descripcio_victimitzacio       Ferit lleu: Amb assistència sanitària en lloc ...
# Coordenada_UTM_X                                                       429910.63
# Coordenada_UTM_Y                                                      4580909.28
# Longitud                                                                2.160723
# Latitud                                                                41.374806
# Name: 0, dtype: object

# %%
data_set = pd.read_csv('2019_accidents_persones_gu_bcn_.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set.iloc[0,:]
data_set.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11844 entries, 0 to 11843
# Data columns (total 30 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Numero_Expedient                         11844 non-null  object
#  1   Codi_districte                           11844 non-null  int64
#  2   Nom_districte                            11844 non-null  object
#  3   Codi_barri                               11844 non-null  int64
#  4   Nom_barri                                11844 non-null  object
#  5   Codi_carrer                              11844 non-null  int64
#  6   Num_postal                               6567 non-null   object
#  7   Num_postal.1                             11844 non-null  object
#  8   Descripcio_dia_setmana                   11844 non-null  object
#  9   Dia_setmana                              11844 non-null  object
#  10  Descripcio_tipus_dia                     11844 non-null  object
#  11  NK_ Any                                  11844 non-null  int64
#  12  Mes_ any                                 11844 non-null  int64
#  13  Nom_mes                                  11844 non-null  object
#  14  Dia_mes                                  11844 non-null  int64
#  15  Descripcio_torn                          11844 non-null  object
#  16  Hora_dia                                 11844 non-null  int64
#  17  Descripcio_causa_vianant                 11844 non-null  object
#  18  Desc_Tipus_vehicle_implicat              11844 non-null  object
#  19  Descripcio_sexe                          11844 non-null  object
#  20  Edat                                     11844 non-null  object
#  21  Descripcio_tipus_persona                 11844 non-null  object
#  22  Descripcio_Lloc_atropellament_vianat     11844 non-null  object
#  23  Descripcio_Motiu_desplaçament_vianant    11844 non-null  object
#  24  Descripcio_Motiu_desplaçament_conductor  11844 non-null  object
#  25  Descripcio_victimitzacio                 11844 non-null  object
#  26  Coordenada_UTM_X                         11844 non-null  object
#  27  Coordenada_UTM_Y                         11844 non-null  object
#  28  Longitud                                 11844 non-null  float64
#  29  Latitud                                  11844 non-null  float64
# dtypes: float64(2), int64(7), object(21)
# memory usage: 2.7+ MB
# There are this number of expedients 11844
# 9255
#   Numero_Expedient  Codi_districte        Nom_districte  Codi_barri  \
# 0  2019S003731                   5  Sarrià-Sant Gervasi          22
# 1  2019S007079                   5  Sarrià-Sant Gervasi          22
# 2  2019S000173                   5  Sarrià-Sant Gervasi          22
# 3  2019S001526                   4            Les Corts          21
# 4  2019S005025                   4            Les Corts          21
#
#                                Nom_barri  Codi_carrer  \
# 0  Vallvidrera, el Tibidabo i les Planes       700059
# 1  Vallvidrera, el Tibidabo i les Planes       700059
# 2  Vallvidrera, el Tibidabo i les Planes       107853
# 3                              Pedralbes       701267
# 4                              Pedralbes       701267
#
#                                           Num_postal Num_postal.1  \
# 0  Vallvidrera a les Planes / Vesc               ...    0050 0050
# 1  Vallvidrera a les Planes                      ...       520000
# 2  Robínia                                       ...    0001 0001
# 3  B-20 (Besòs)                                  ...       460000
# 4  Dalt (Besòs)                                  ...       480000
#
#   Descripcio_dia_setmana Dia_setmana  ... Edat  Descripcio_tipus_persona  \
# 0               Dimecres          Dc  ...   30                 Conductor
# 1              Divendres          Dv  ...   47                 Conductor
# 2                Dimarts          Dm  ...   55                 Conductor
# 3                Dimarts          Dm  ...   40                 Conductor
# 4                 Dijous          Dj  ...   30                 Conductor
#
#                 Descripcio_Lloc_atropellament_vianat  \
# 0  N/A                                           ...
# 1  N/A                                           ...
# 2  N/A                                           ...
# 3  N/A                                           ...
# 4  N/A                                           ...
#
#   Descripcio_Motiu_desplaçament_vianant  \
# 0                            Desconegut
# 1                            Desconegut
# 2                            Desconegut
# 3                            Desconegut
# 4                            Desconegut
#
#    Descripcio_Motiu_desplaçament_conductor  \
# 0                               In itinere
# 1    Transport professional de mercaderies
# 2                             Es desconeix
# 3                               In itinere
# 4                             Es desconeix
#
#                             Descripcio_victimitzacio  Coordenada_UTM_X  \
# 0         Ferit greu: hospitalització superior a 24h        424364.44
# 1          Ferit lleu: Rebutja assistència sanitària        424664.63
# 2             Ferit lleu: Hospitalització fins a 24h        424953.07
# 3             Ferit lleu: Hospitalització fins a 24h        424991.14
# 4  Ferit lleu: Amb assistència sanitària en lloc ...        425098.69
#
#   Coordenada_UTM_Y  Longitud    Latitud
# 0       4586356.76  2.093635  41.423385
# 1       4585896.4   2.097285  41.419267
# 2       4586589.22  2.100650  41.425534
# 3       4581760.18  2.101704  41.382045
# 4       4581932.44  2.102969  41.383607
#
# [5 rows x 30 columns]

# %%
data_set = pd.read_csv('2020_accidents_persones_gu_bcn.csv',sep = ",")
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set.iloc[0,:]
data_set.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13810 entries, 0 to 13809
# Data columns (total 30 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Numero_Expedient                          13810 non-null  object
#  1   Codi_districte                            13810 non-null  int64
#  2   Nom_districte                             13810 non-null  object
#  3   Codi_barri                                13810 non-null  int64
#  4   Nom_barri                                 13810 non-null  object
#  5   Codi_carrer                               13810 non-null  int64
#  6   Nom_carrer                                13810 non-null  object
#  7   Num_postal                                13810 non-null  object
#  8   Descripcio_dia_setmana                    13810 non-null  object
#  9   Dia_setmana                               13810 non-null  int64
#  10  Descripcio_tipus_dia                      13810 non-null  object
#  11  NK_ Any                                   13810 non-null  int64
#  12  Mes_ any                                  13810 non-null  int64
#  13  Nom_mes                                   13810 non-null  object
#  14  Dia_mes                                   13810 non-null  int64
#  15  Descripcio_torn                           13810 non-null  object
#  16  Hora_dia                                  13810 non-null  int64
#  17  Descripcio_causa_vianant                  13810 non-null  object
#  18  Desc_Tipus_vehicle_implicat               13810 non-null  object
#  19  Descripció_sexe                           13810 non-null  object
#  20  Edat                                      13810 non-null  int64
#  21  Descripció_tipus_persona                  13810 non-null  object
#  22  Descripcio_Lloc_atropellament_vianat      13810 non-null  object
#  23  Descripcio_Motiu_desplaĂ§ament_vianant    13810 non-null  object
#  24  Descripcio_Motiu_desplaĂ§ament_conductor  13810 non-null  object
#  25  Descripcio_victimitzacio                  13810 non-null  object
#  26  Coordenada_UTM_X                          13810 non-null  float64
#  27  Coordenada_UTM_Y                          13810 non-null  float64
#  28  Longitud                                  13810 non-null  float64
#  29  Latitud                                   13810 non-null  float64
# dtypes: float64(4), int64(9), object(17)
# memory usage: 3.2+ MB
# There are this number of expedients 13810
# 6257
#   Numero_Expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0  2020S000001                   7  Horta-Guinardó          36
# 1  2020S000002                   3  Sants-Montjuďc          16
# 2  2020S000002                   3  Sants-Montjuďc          16
# 3  2020S000003                   2        Eixample           8
# 4  2020S000003                   2        Eixample           8
#
#                          Nom_barri  Codi_carrer       Nom_carrer Num_postal  \
# 0             la Font d'en Fargues       194406         Maragall  0353 0355
# 1                       la Bordeta       169409  Corts Catalanes  0203 0203
# 2                       la Bordeta       169409  Corts Catalanes  0203 0203
# 3  l'Antiga Esquerra de l'Eixample       320704           Sarriŕ  0018 0018
# 4  l'Antiga Esquerra de l'Eixample       320704           Sarriŕ  0018 0018
#
#   Descripcio_dia_setmana  Dia_setmana  ... Edat  Descripció_tipus_persona  \
# 0               Dimecres     20200101  ...   29                 Conductor
# 1               Dimecres     20200101  ...   26                   Vianant
# 2               Dimecres     20200101  ...   31                 Conductor
# 3               Dimecres     20200101  ...   42                 Conductor
# 4               Dimecres     20200101  ...   36                 Conductor
#
#                 Descripcio_Lloc_atropellament_vianat  \
# 0  Desconegut                                    ...
# 1  En pas regulat per semŕfor                    ...
# 2  En pas regulat per semŕfor                    ...
# 3  Desconegut                                    ...
# 4  Desconegut                                    ...
#
#   Descripcio_Motiu_desplaĂ§ament_vianant  \
# 0                             Desconegut
# 1                    Oci i entreteniment
# 2                             Desconegut
# 3                             Desconegut
# 4                             Desconegut
#
#    Descripcio_Motiu_desplaĂ§ament_conductor  \
# 0                              Es desconeix
# 1                                Desconegut
# 2                                      Taxi
# 3                       Oci i entreteniment
# 4                                      Taxi
#
#                  Descripcio_victimitzacio  Coordenada_UTM_X Coordenada_UTM_Y  \
# 0                                  Il.lčs         430501.45       4586751.53
# 1  Ferit lleu: Hospitalització fins a 24h         428225.71       4580279.72
# 2                                  Il.lčs         428225.71       4580279.72
# 3  Ferit lleu: Hospitalització fins a 24h         428532.59       4582672.59
# 4                                  Il.lčs         428532.59       4582672.59
#
#    Longitud    Latitud
# 0  2.167116  41.427474
# 1  2.140650  41.368985
# 2  2.140650  41.368985
# 3  2.144037  41.390564
# 4  2.144037  41.390564
#
# [5 rows x 30 columns]

# %%
data_set = pd.read_csv('2021_accidents_persones_gu_bcn.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8854 entries, 0 to 8853
# Data columns (total 28 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Numero_Expedient                          8854 non-null   object
#  1   Codi_districte                            8854 non-null   int64
#  2   Nom_districte                             8854 non-null   object
#  3   Codi_barri                                8854 non-null   int64
#  4   Nom_barri                                 8854 non-null   object
#  5   Codi_carrer                               8854 non-null   int64
#  6   Nom_carrer                                8854 non-null   object
#  7   Num_postal                                8854 non-null   object
#  8   Descripcio_dia_setmana                    8854 non-null   object
#  9   NK_ Any                                   8854 non-null   int64
#  10  Mes_ any                                  8854 non-null   int64
#  11  Nom_mes                                   8854 non-null   object
#  12  Dia_mes                                   8854 non-null   int64
#  13  Descripcio_torn                           8854 non-null   object
#  14  Hora_dia                                  8854 non-null   int64
#  15  Descripcio_causa_vianant                  8854 non-null   object
#  16  Desc_Tipus_vehicle_implicat               8854 non-null   object
#  17  Descripció_sexe                           8854 non-null   object
#  18  Edat                                      8854 non-null   object
#  19  Descripció_tipus_persona                  8854 non-null   object
#  20  Descripcio_Lloc_atropellament_vianat      8854 non-null   object
#  21  Descripcio_Motiu_desplaÃ§ament_vianant    8854 non-null   object
#  22  Descripcio_Motiu_desplaÃ§ament_conductor  8854 non-null   object
#  23  Descripcio_victimitzacio                  8854 non-null   object
#  24  Coordenada_UTM_X_ED50                     8854 non-null   float64
#  25  Coordenada_UTM_Y_ED50                     8854 non-null   float64
#  26  Longitud_WGS84                            8825 non-null   float64
#  27  Latitud_WGS84                             8825 non-null   float64
# dtypes: float64(4), int64(7), object(17)
# memory usage: 1.9+ MB
# There are this number of expedients 8854
# 7001
# Numero_Expedient                                                              2021S001906
# Codi_districte                                                                              1
# Nom_districte                                                                    Ciutat Vella
# Codi_barri                                                                                  1
# Nom_barri                                                                            el Raval
# Codi_carrer                                                                             68503
# Nom_carrer                                                                           Carretes
# Num_postal                                                                          0044 0044
# Descripcio_dia_setmana                                                                Dimarts
# NK_ Any                                                                                  2021
# Mes_ any                                                                                    4
# Nom_mes                                                                                 Abril
# Dia_mes                                                                                    13
# Descripcio_torn                                                                         Tarda
# Hora_dia                                                                                   20
# Descripcio_causa_vianant                                             No és causa del  vianant
# Desc_Tipus_vehicle_implicat                                                         Bicicleta
# Descripció_sexe                                                                          Dona
# Edat                                                                                        8
# Descripció_tipus_persona                                                              Vianant
# Descripcio_Lloc_atropellament_vianat        A la vorera / Andana                          ...
# Descripcio_Motiu_desplaÃ§ament_vianant                                    Oci i entreteniment
# Descripcio_Motiu_desplaÃ§ament_conductor                                           Desconegut
# Descripcio_victimitzacio                               Ferit lleu: Hospitalització fins a 24h
# Coordenada_UTM_X_ED50                                                               430455.95
# Coordenada_UTM_Y_ED50                                                              4581207.96
# Longitud_WGS84                                                                       2.167209
# Latitud_WGS84                                                                       41.377541
# Name: 0, dtype: object

# %%
data_set = pd.read_csv('2022_accidents_persones_gu_bcn.csv',sep = ",")
data_set
data_set.info()
numer_exp=data_set.iloc[:,0]
numer_exp1= len(numer_exp)
print('There are this number of expedients'+' '+str(numer_exp1))
real_people= numer_exp.drop_duplicates()
real=len(real_people)
print(real)
data_set.iloc[0,:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9065 entries, 0 to 9064
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Numero_expedient                         9065 non-null   object
#  1   Codi_districte                           9065 non-null   int64
#  2   Nom_districte                            9065 non-null   object
#  3   Codi_barri                               9065 non-null   int64
#  4   Nom_barri                                9065 non-null   object
#  5   Codi_carrer                              9065 non-null   int64
#  6   Nom_carrer                               9065 non-null   object
#  7   Num_postal                               9065 non-null   object
#  8   Descripcio_dia_setmana                   9065 non-null   object
#  9   NK_ Any                                  9065 non-null   int64
#  10  Mes_ any                                 9065 non-null   int64
#  11  Nom_mes                                  9065 non-null   object
#  12  Dia_mes                                  9065 non-null   int64
#  13  Descripcio_torn                          9065 non-null   object
#  14  Hora_dia                                 9065 non-null   int64
#  15  Descripcio_causa_vianant                 9065 non-null   object
#  16  Desc_Tipus_vehicle_implicat              9065 non-null   object
#  17  Descripcio_sexe                          9065 non-null   object
#  18  Edat                                     9065 non-null   object
#  19  Descripcio_tipus_persona                 9065 non-null   object
#  20  Descripcio_Lloc_atropellament_vianant    9065 non-null   object
#  21  Descripcio_Motiu_desplaçament_vianant    9065 non-null   object
#  22  Descripcio_Motiu_desplaçament_conductor  9065 non-null   object
#  23  Descripcio_victimitzacio                 9065 non-null   object
#  24  Coordenada_UTM_X_ED50                    9065 non-null   object
#  25  Coordenada_UTM_Y_ED50                    9065 non-null   object
#  26  Longitud                                 8972 non-null   float64
#  27  Latitud                                  8972 non-null   float64
# dtypes: float64(2), int64(7), object(19)
# memory usage: 1.9+ MB
# There are this number of expedients 9065
# 7206
# Numero_expedient                                                             2022S000001
# Codi_districte                                                                             2
# Nom_districte                                                                       Eixample
# Codi_barri                                                                                 9
# Nom_barri                                                     la Nova Esquerra de l'Eixample
# Codi_carrer                                                                           110803
# Nom_carrer                                                                           Entença
# Num_postal                                                                        0198B0198B
# Descripcio_dia_setmana                                                              Dissabte
# NK_ Any                                                                                 2022
# Mes_ any                                                                                   1
# Nom_mes                                                                                Gener
# Dia_mes                                                                                    1
# Descripcio_torn                                                                          Nit
# Hora_dia                                                                                   1
# Descripcio_causa_vianant                                            No és causa del  vianant
# Desc_Tipus_vehicle_implicat                                                      Motocicleta
# Descripcio_sexe                                                                         Dona
# Edat                                                                                      31
# Descripcio_tipus_persona                                                           Conductor
# Descripcio_Lloc_atropellament_vianant      Desconegut                                    ...
# Descripcio_Motiu_desplaçament_vianant                                             Desconegut
# Descripcio_Motiu_desplaçament_conductor                                  Oci i entreteniment
# Descripcio_victimitzacio                   Ferit lleu: Amb assistència sanitària en lloc ...
# Coordenada_UTM_X_ED50                                                              428502.72
# Coordenada_UTM_Y_ED50                                                             4582056.71
# Longitud                                                                            2.144854
# Latitud                                                                            41.386863
# Name: 0, dtype: object
