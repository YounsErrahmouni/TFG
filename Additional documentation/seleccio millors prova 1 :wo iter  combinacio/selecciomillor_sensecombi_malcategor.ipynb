# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
persones=pd.read_csv('Accident_people_2021_2022.csv')
persones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17919 entries, 0 to 17918
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    17919 non-null  int64
#  1   File_Num                      17919 non-null  object
#  2   District                      17919 non-null  object
#  3   Neighbourhood                 17919 non-null  object
#  4   Street_name                   17919 non-null  object
#  5   Day_name                      17919 non-null  object
#  6   year                          17919 non-null  int64
#  7   month                         17919 non-null  int64
#  8   Month_name                    17919 non-null  object
#  9   day                           17919 non-null  int64
#  10  Day_shift                     17919 non-null  object
#  11  hour                          17919 non-null  int64
#  12  Pedestrian_situation          17919 non-null  object
#  13  Vehicle_type                  17919 non-null  object
#  14  Gender                        17919 non-null  object
#  15  Age                           17919 non-null  object
#  16  Person_type                   17919 non-null  object
#  17  Pedestrian_accident_location  17919 non-null  object
#  18  Pedestrian_intention          17919 non-null  object
#  19  Driver_intention              17919 non-null  object
#  20  Accident_severity             17919 non-null  object
#  21  Date                          17919 non-null  object
# dtypes: int64(5), object(17)
# memory usage: 3.0+ MB

# %%
weather=pd.read_csv('data_meteo_estudifinal_2021_2022.csv')
weather = weather.drop(weather.columns[0], axis=1)
weather.rename(columns={'DATA_LECTURA':'Date'},inplace=True)
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       35040 non-null  object
#  1   03.TM      35040 non-null  float64
#  2   06.HRM     35040 non-null  float64
#  3   07.PPT24H  35040 non-null  float64
#  4   08.HPA     35040 non-null  float64
#  5   09.RS24H   35040 non-null  float64
#  6   10.VVM10   35040 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 1.9+ MB

# %%
persones= persones[persones['Person_type'] == 'Driver']
persones.head()
# Out:
#     Unnamed: 0         File_Num      District  \
# 6            6  2021S003310      Ciutat Vella
# 8            8  2021S001728      Ciutat Vella
# 17          17  2021S005721          Eixample
# 31          31  2021S005403          Eixample
# 39          39  2021S004164          Eixample
#
#                       Neighbourhood    Street_name   Day_name  year  month  \
# 6                    el Barri Gòtic      Catalunya     Dijous  2021      6
# 8                    la Barceloneta         Marina   Diumenge  2021      4
# 17                    el Fort Pienc         Marina   Dimecres  2021     10
# 31  l'Antiga Esquerra de l'Eixample          Aragó   Dimecres  2021      9
# 39                      Sant Antoni  Comte Borrell  Divendres  2021      7
#
#    Month_name  day  ...  Pedestrian_situation           Vehicle_type Gender  \
# 6        Juny   17  ...  Not pedestrian fault  Vehicle without motor    Men
# 8       Abril    4  ...             Not known  Vehicle without motor  Women
# 17    Octubre   13  ...  Not pedestrian fault                  Other  Women
# 31   Setembre   29  ...  Not pedestrian fault                    Car    Men
# 39     Juliol   23  ...  Not pedestrian fault             Motorcycle    Men
#
#    Age Person_type                       Pedestrian_accident_location  \
# 6   31      Driver  A la vorera / Andana                          ...
# 8   45      Driver  A la vorera / Andana                          ...
# 17  51      Driver  A la vorera / Andana                          ...
# 31  71      Driver  A la vorera / Andana                          ...
# 39  24      Driver  A la vorera / Andana                          ...
#
#    Pedestrian_intention     Driver_intention Accident_severity  \
# 6            Desconegut  Oci i entreteniment        Assistance
# 8            Desconegut  Oci i entreteniment      Hospitalized
# 17           Desconegut           In itínere      Hospitalized
# 31           Desconegut  Oci i entreteniment        Assistance
# 39           Desconegut    Altres activitats      Hospitalized
#
#                    Date
# 6   2021-06-17 20:00:00
# 8   2021-04-04 10:00:00
# 17  2021-10-13 08:00:00
# 31  2021-09-29 09:00:00
# 39  2021-07-23 19:00:00
#
# [5 rows x 22 columns]

# %%
#FROM ALL THE DATA WE ARE JUST GOING TO FOCUS N¡ON THE DRIVERS BECAUSE
#THE PASSANGER OR THE PEDESTRIAN DOESN0T HAVE ANY KIND OF POWER TO NOT BE IN THE SITUATION OR HAVE ANY CONTROL

persones=persones[['Day_shift','Vehicle_type','Gender','Age','Date']]
weather=weather[['Date','03.TM','06.HRM','10.VVM10']]

#JOIN THE DATASETS WITH THE VARIABLE DATE
variables = pd.merge(persones, weather, on='Date', how='left')
variables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12681 entries, 0 to 12680
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Day_shift     12681 non-null  object
#  1   Vehicle_type  12681 non-null  object
#  2   Gender        12681 non-null  object
#  3   Age           12681 non-null  object
#  4   Date          12681 non-null  object
#  5   03.TM         12681 non-null  float64
#  6   06.HRM        12681 non-null  float64
#  7   10.VVM10      12681 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 891.6+ KB

# %%
#add variable quarter and start studying the different variables
variables['Quarter'] = variables['Date'].apply(lambda x: pd.Timestamp(x).quarter)
variables.head()
# Out:
#    Day_shift           Vehicle_type Gender Age                 Date  03.TM  \
# 0  Afternoon  Vehicle without motor    Men  31  2021-06-17 20:00:00   23.4
# 1    Morning  Vehicle without motor  Women  45  2021-04-04 10:00:00   15.9
# 2    Morning                  Other  Women  51  2021-10-13 08:00:00   19.3
# 3    Morning                    Car    Men  71  2021-09-29 09:00:00   23.5
# 4  Afternoon             Motorcycle    Men  24  2021-07-23 19:00:00   27.7
#
#    06.HRM  10.VVM10  Quarter
# 0    97.0       1.1        2
# 1    55.0       2.3        2
# 2    65.0       1.0        4
# 3    64.0       1.4        3
# 4    53.0       0.8        3

# %%
# LETS TRANSFORM TO CATHEGORIC THE COLUMN EDAT
#'youth' if their age value is lower than 21, 'young adult' from 21 to 31, 'adult' from 32 to 50, 'old' from 51 /// desconegut(404) -->NOT KNOWN
#transform value desconegut a 404
variables['Age'] = variables['Age'].replace('Desconegut', '404')
def categorize_age(age):
    if int(age) <= 23:
        return 'Kid'
    elif int(age) <= 30 and int(age) > 23:
        return 'Youth'
    elif int(age) <= 50 and int(age) > 30:
        return 'Adult'
    elif age == '404':
        return 'Not known'
    else:
        return 'Old'

# Apply function to transform ages to categories
variables['Age'] = variables['Age'].apply(categorize_age)

x=variables['Age'].unique()
print(x)

# count the frequency of each value in column 'a'
value_counts = variables['Age'].value_counts()

# calculate the percentage of times each value appears
percentage = (value_counts / len(variables)) * 100
print(percentage)
# Out:
# ['Adult' 'Old' 'Youth' 'Kid' 'Not known']
# Adult        46.266067
# Youth        21.867361
# Old          19.888021
# Kid          11.931236
# Not known     0.047315
# Name: Age, dtype: float64

# %%
#x=variables['03.TM'].unique()
# print(np.sort(x)) the data goes from 3.8 to 34.2
def cat_temp(temp):
    if int(temp) <= 13:
        return 'Very low'
    elif int(temp) <= 17 and int(temp) > 13:
        return 'Low'
    elif int(temp) <= 24 and int(temp) > 17:
        return 'Mild'
    else:
        return 'Hot'
variables['03.TM'] = variables['03.TM'].apply(cat_temp)

x=variables['03.TM'].unique()
print(x)

# count the frequency of each value in column 'a'
value_counts = variables['03.TM'].value_counts()

# calculate the percentage of times each value appears
percentage = (value_counts / len(variables)) * 100
print(percentage)
# Out:
# ['Mild' 'Low' 'Hot' 'Very low']
# Mild        30.273638
# Very low    25.045343
# Hot         23.200063
# Low         21.480956
# Name: 03.TM, dtype: float64

# %%
#x=variables['06.HRM'].unique()
#print(np.sort(x)) from 9 percent to 100 percent
def cat_humidity(hum):
    if int(hum) <= 48:
        return 'Low'
    elif int(hum) <= 60 and int(hum) > 48:
        return 'Moderate'
    elif int(hum) <= 75 and int(hum) > 60:
        return 'High'
    else:
        return 'Very high'
variables['06.HRM'] = variables['06.HRM'].apply(cat_humidity)

x=variables['06.HRM'].unique()
print(x)

# count the frequency of each value in column 'a'
value_counts = variables['06.HRM'].value_counts()

# calculate the percentage of times each value appears
percentage = (value_counts / len(variables)) * 100
print(percentage)
# Out:
# ['Very high' 'Moderate' 'High' 'Low']
# High         39.216150
# Moderate     25.234603
# Low          19.075783
# Very high    16.473464
# Name: 06.HRM, dtype: float64

# %%
#x=variables['10.VVM10'].unique()
#print(np.sort(x)) from 0 to 8.7
#x=variables['06.HRM'].unique()
#print(np.sort(x)) from 9 percent to 100 percent
def cat_wind(wind):
    if int(wind) <= 1:
        return 'Low'
    elif int(wind) <= 2 and int(wind) > 1:
        return 'Moderate'
    else:
        return 'High'
    
variables['10.VVM10'] = variables['10.VVM10'].apply(cat_wind)

x=variables['10.VVM10'].unique()
print(x)

# count the frequency of each value in column 'a'
value_counts = variables['10.VVM10'].value_counts()

# calculate the percentage of times each value appears
percentage = (value_counts / len(variables)) * 100
print(percentage)
# Out:
# ['Low' 'Moderate' 'High']
# Low         43.080199
# Moderate    30.344610
# High        26.575191
# Name: 10.VVM10, dtype: float64

# %%
from itertools import combinations
from sklearn import preprocessing
from kmodes.kmodes import KModes
# List of variable names
variables_name = ['Day_shift', 'Vehicle_type', 'Gender', 'Age', '03.TM', '06.HRM', '10.VVM10', 'Quarter']

# Generate combinations of 5 variables
comb = combinations(variables_name, 5)

# Empty DataFrame to store results
table = pd.DataFrame()
def tuple_to_list(t):
    new_list = []
    for element in t:
        new_list.append(element)
    return new_list

# Iterate over combinations
for selected_columns in comb:
    # Select columns from 'variables' DataFrame based on the combination
    listavar=tuple_to_list(selected_columns)
    subgrup_1 = variables[listavar]

    # Clustering code
    subgroup = subgrup_1.copy()
    from sklearn import preprocessing  
    le = preprocessing.LabelEncoder()
    subgroup_encoded = subgroup.apply(le.fit_transform)
    #to create the list to get the percenge of significant clusters
    l=[]
    # Iterate through cluster numbers
    for n_clusters in range(3, 16):
        # Clustering
        km = KModes(n_clusters=n_clusters, init='Cao', n_init=1, verbose=1)
        clusters = km.fit_predict(subgroup_encoded)

        # Combine with original data
        combined = pd.concat([subgroup.reset_index(), pd.DataFrame({'Cluster': clusters})], axis=1).drop('index', axis=1)

        # Create table
        table = pd.DataFrame(columns=range(n_clusters))

        # Fill in table with percentage of instances of each value in each cluster for each variable
        for var in subgroup.columns:
            by_cluster_value = combined.groupby(['Cluster', var]).size()
            percentages = by_cluster_value.groupby(level=0).apply(lambda x: x / x.sum() * 100)
            pivot_table = pd.pivot_table(percentages.reset_index(), index=var, columns='Cluster', values=0, fill_value=0)

            # Fill in table with percentage of instances for each value in each cluster
            for i, col in enumerate(pivot_table.columns):
                values = pivot_table[col].index.tolist()
                pct_values = pivot_table[col].tolist()
                for j, value in enumerate(values):
                    table.loc[value, i] = pct_values[j]
            # Add new column with variable names based on index
        table['VARIABLE'] = ''

        variable_mapping = {}

        for column in subgroup.columns:
            unique_values = subgroup[column].unique()
            variable_mapping[column] = unique_values

        for i, index_value in enumerate(table.index.values):
            for variable, values in variable_mapping.items():
                if index_value in values:
                    table.iloc[i, -1] = variable
                    break

        table = table.reset_index().rename(columns={'index': 'value'})
        table = table[['VARIABLE'] + list(table.columns[:-1])]
        table = table.set_index('VARIABLE')       

        # Add a new row for the cluster totals
        table.loc['Cluster percentage of drivers'] = 0

        # Calculate the number of instances in each cluster
        cluster_counts = combined['Cluster'].value_counts()

        # Fill in the table with the percentage of instances in each cluster
        for i, count in cluster_counts.items():
            table.loc['Cluster percentage of drivers', i] = count / len(combined) * 100
    
        #table.to_excel(f'table_{n_clusters}_clusters_pas1.xlsx', index=True)
        table1=table
        # Save table to CSV file
        table = table.drop('value', axis=1)
        new_table_2 = pd.DataFrame(index=table.index.unique())
    # Iterate over each column (0, 1, 2, 3) and find the highest percentage for each variable
        for col in table.columns:
            col_max = table.groupby(level=0)[col].max()
            new_table_2[col] = col_max
    # Add the 'Cluster percentage of drivers' row back to the new DataFrame
        new_table_2.loc['Cluster percentage of drivers'] = table.loc['Cluster percentage of drivers']
    # Display the new DataFrame
        #print(new_table_2)
        #new_table_2.to_excel(f'table_{n_clusters}_clusters_pas2.xlsx', index=True)
        new_table_3= new_table_2.loc[new_table_2.index != 'Cluster percentage of drivers'] = (new_table_2.loc[new_table_2.index != 'Cluster percentage of drivers'] >= 75).astype(int)
        new_table_3.loc['number of significant variables'] = new_table_3.sum()
        #new_table_2.to_excel(f'table_{n_clusters}_clusters_pas3.xlsx', index=True)
        #print(new_table_3)  
        new_table_3.loc['Cluster significance'] = new_table_3 .loc['number of significant variables'] / 5
        new_table_3.loc['Cluster significant?'] = new_table_3 .loc['Cluster significance']>=0.5
        new_table_4=new_table_3
        new_table_4.loc['Cluster percentage of drivers'] = table.loc['Cluster percentage of drivers']
        new_table_4.loc['Significant clusters'] = np.nan
    # Add a column with the percentage of significant cluster
        new_table_4.loc['Significant clusters' ,'percentage of significant cluster'] = new_table_4.loc['Cluster significant?'].sum() / n_clusters
    # Transpose the dataframe back to its original orientation
    # Print the resulting dataframe
        if new_table_4.loc['Cluster significant?'].sum() / n_clusters > 0.7:
            table1.to_excel(f'table_{n_clusters}_clusters_{"".join(selected_columns)}.xlsx', index=True)
    #new_table_4.to_excel(f'table_{n_clusters}_clusters_{"".join(selected_columns)}.xlsx', index=True)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23671.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22308.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21230.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20457.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19288.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18540.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18013.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17413.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16997.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16639.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16164.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15553.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14995.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22959.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22007.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20857.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20185.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19240.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18474.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17895.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17463.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16839.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16136.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15631.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15347.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22393.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21050.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1023, cost: 19548.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 967, cost: 18608.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 899, cost: 18097.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 899, cost: 17476.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 899, cost: 16872.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 899, cost: 16029.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 889, cost: 15423.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 889, cost: 14509.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 887, cost: 14032.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 869, cost: 13639.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 869, cost: 12982.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24132.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22694.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21535.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20822.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19681.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18843.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18227.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17555.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17157.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16786.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16208.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15358.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14767.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24130.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22607.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21713.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20504.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19598.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18782.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18294.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17708.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17424.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16861.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16355.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15945.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15537.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23484.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1474, cost: 21266.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1364, cost: 20195.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1241, cost: 19615.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1241, cost: 18405.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1209, cost: 17685.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1205, cost: 17019.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1175, cost: 16322.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1175, cost: 15816.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1595, cost: 14962.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1362, cost: 14633.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1345, cost: 14241.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1320, cost: 13756.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25423.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23891.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22893.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21542.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20675.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19525.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18724.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18075.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17584.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17038.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15912.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15406.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15169.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22724.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1370, cost: 20704.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1215, cost: 19869.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1209, cost: 18692.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1101, cost: 18146.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1086, cost: 17425.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1103, cost: 17064.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1102, cost: 16148.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1102, cost: 15517.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1080, cost: 15131.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1080, cost: 14595.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1080, cost: 13953.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1069, cost: 13189.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24432.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23017.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22191.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20988.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19951.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19010.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18451.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18022.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17585.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16922.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16453.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15997.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15529.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23642.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1592, cost: 21443.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1495, cost: 20322.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1322, cost: 19687.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1322, cost: 18713.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1281, cost: 17864.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1282, cost: 17320.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1248, cost: 16532.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1248, cost: 16104.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 989, cost: 15544.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 977, cost: 14703.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 977, cost: 13857.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 942, cost: 13461.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26224.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24559.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23086.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22083.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21052.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20463.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19723.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19219.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18684.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18353.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17819.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17493.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17222.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25639.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23840.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22411.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21060.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 447, cost: 20217.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19662.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18739.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18067.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17529.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 173, cost: 17086.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 173, cost: 16656.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 173, cost: 16273.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 173, cost: 15941.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 27794.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26581.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24905.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23510.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22876.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22055.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 330, cost: 21092.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 337, cost: 20171.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 327, cost: 19442.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 305, cost: 19198.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 305, cost: 18773.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 310, cost: 18474.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 332, cost: 18200.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24715.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23005.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21829.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20945.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20453.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19514.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18838.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18414.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17847.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17322.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16884.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16485.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16070.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26500.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24797.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23395.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22362.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21507.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20770.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19983.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19348.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18796.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18309.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17952.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17538.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17331.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25680.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23917.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22574.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21102.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20398.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19399.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18718.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17926.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17564.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17131.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16935.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16619.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16227.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26132.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24218.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22639.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21357.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20598.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 412, cost: 19696.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 363, cost: 19114.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 363, cost: 18345.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 363, cost: 17921.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 360, cost: 17444.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 515, cost: 16901.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 515, cost: 16496.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 515, cost: 16235.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 28441.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25888.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23979.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22728.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21555.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20943.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20374.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20060.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19480.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18875.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18619.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18238.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17920.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1111, cost: 25918.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 904, cost: 24665.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 893, cost: 23047.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 714, cost: 21349.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 703, cost: 20425.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 745, cost: 19791.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 732, cost: 19419.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 729, cost: 18730.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 718, cost: 18242.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 724, cost: 17620.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 697, cost: 17251.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 697, cost: 16998.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 683, cost: 16788.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1028, cost: 25588.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1025, cost: 23952.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1119, cost: 22927.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 925, cost: 21868.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1192, cost: 20722.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1130, cost: 19903.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1114, cost: 18980.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1105, cost: 18398.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1091, cost: 17897.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1003, cost: 17607.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 976, cost: 17367.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 951, cost: 17018.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 950, cost: 16764.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25564.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24120.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22940.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21660.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20666.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19716.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19157.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18598.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17656.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17171.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16715.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16275.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15975.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24952.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23467.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22126.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20798.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 674, cost: 19719.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 674, cost: 19075.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 674, cost: 17930.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 674, cost: 17246.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 657, cost: 17080.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 515, cost: 16667.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 515, cost: 15770.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 515, cost: 15453.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 502, cost: 14885.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26688.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25275.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23877.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22448.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21309.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20561.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19657.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18734.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18343.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17758.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17309.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16998.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16730.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24150.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22843.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21403.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20245.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19551.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19009.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18017.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17577.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17330.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16506.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15875.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15143.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14581.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25740.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24220.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23135.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21980.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20894.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19943.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19421.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18604.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18175.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17517.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17083.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16425.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15901.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24981.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23325.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21727.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20473.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19715.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19045.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18090.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17591.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17057.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16534.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16057.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15811.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15238.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25392.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23886.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22060.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20877.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20319.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19193.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 610, cost: 18221.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 610, cost: 17508.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 601, cost: 17307.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 601, cost: 16918.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 478, cost: 16548.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 478, cost: 15785.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 471, cost: 15333.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 27078.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25584.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24408.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23352.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22432.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21493.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 704, cost: 20179.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 693, cost: 19406.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 693, cost: 19063.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 693, cost: 18378.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18194.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17883.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17428.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26268.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24703.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1147, cost: 22114.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1980, cost: 20493.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1968, cost: 19966.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# ...
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21582.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20913.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20171.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19586.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19208.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18875.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18503.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 28236.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25800.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24276.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23377.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22345.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21822.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20972.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20228.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19814.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19503.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18831.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18557.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18037.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 27277.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25410.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24231.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23013.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22265.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21513.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20799.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20104.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19661.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18928.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18476.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18146.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17732.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 28150.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25922.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24592.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23236.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22657.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22116.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21067.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20589.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20056.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 606, cost: 19079.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 606, cost: 18577.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 606, cost: 18319.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 606, cost: 17783.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26560.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24742.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23613.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 932, cost: 22023.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 931, cost: 21127.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 903, cost: 20387.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 877, cost: 19673.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 828, cost: 19331.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 866, cost: 19020.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 866, cost: 18495.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 858, cost: 18037.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 816, cost: 17553.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 803, cost: 16716.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 28664.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26382.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25392.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24101.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23530.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22596.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21994.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20958.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20210.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19587.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19049.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18695.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18086.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 27519.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25129.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23645.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22897.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21881.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20983.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20274.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 340, cost: 19023.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 340, cost: 18473.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 340, cost: 17785.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 340, cost: 17504.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 340, cost: 16965.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 315, cost: 16207.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26560.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24548.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23362.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22501.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21661.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20820.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19902.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19078.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18593.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18091.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17576.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16940.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16620.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 27433.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25292.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23925.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22860.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21778.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21229.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 20566.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 19129.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 18407.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17781.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 17219.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16962.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 16418.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 30705.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 28941.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 27813.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 26853.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 25630.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 24502.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23761.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 23105.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22536.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22142.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21784.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21410.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 21097.0
