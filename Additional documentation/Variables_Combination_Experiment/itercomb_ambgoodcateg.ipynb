# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
persones=pd.read_csv('Accident_people_2021_2022.csv')
persones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17919 entries, 0 to 17918
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    17919 non-null  int64
#  1   File_Num                      17919 non-null  object
#  2   District                      17919 non-null  object
#  3   Neighbourhood                 17919 non-null  object
#  4   Street_name                   17919 non-null  object
#  5   Day_name                      17919 non-null  object
#  6   year                          17919 non-null  int64
#  7   month                         17919 non-null  int64
#  8   Month_name                    17919 non-null  object
#  9   day                           17919 non-null  int64
#  10  Day_shift                     17919 non-null  object
#  11  hour                          17919 non-null  int64
#  12  Pedestrian_situation          17919 non-null  object
#  13  Vehicle_type                  17919 non-null  object
#  14  Gender                        17919 non-null  object
#  15  Age                           17919 non-null  object
#  16  Person_type                   17919 non-null  object
#  17  Pedestrian_accident_location  17919 non-null  object
#  18  Pedestrian_intention          17919 non-null  object
#  19  Driver_intention              17919 non-null  object
#  20  Accident_severity             17919 non-null  object
#  21  Date                          17919 non-null  object
# dtypes: int64(5), object(17)
# memory usage: 3.0+ MB

# %%
weather=pd.read_csv('data_meteo_estudifinal_2021_2022.csv')
weather = weather.drop(weather.columns[0], axis=1)
weather.rename(columns={'DATA_LECTURA':'Date'},inplace=True)
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       35040 non-null  object
#  1   03.TM      35040 non-null  float64
#  2   06.HRM     35040 non-null  float64
#  3   07.PPT24H  35040 non-null  float64
#  4   08.HPA     35040 non-null  float64
#  5   09.RS24H   35040 non-null  float64
#  6   10.VVM10   35040 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 1.9+ MB

# %%
persones= persones[persones['Person_type'] == 'Driver']
persones.head()
# Out:
#     Unnamed: 0         File_Num      District  \
# 6            6  2021S003310      Ciutat Vella
# 8            8  2021S001728      Ciutat Vella
# 17          17  2021S005721          Eixample
# 31          31  2021S005403          Eixample
# 39          39  2021S004164          Eixample
#
#                       Neighbourhood    Street_name   Day_name  year  month  \
# 6                    el Barri Gòtic      Catalunya     Dijous  2021      6
# 8                    la Barceloneta         Marina   Diumenge  2021      4
# 17                    el Fort Pienc         Marina   Dimecres  2021     10
# 31  l'Antiga Esquerra de l'Eixample          Aragó   Dimecres  2021      9
# 39                      Sant Antoni  Comte Borrell  Divendres  2021      7
#
#    Month_name  day  ...  Pedestrian_situation           Vehicle_type Gender  \
# 6        Juny   17  ...  Not pedestrian fault  Vehicle without motor    Men
# 8       Abril    4  ...             Not known  Vehicle without motor  Women
# 17    Octubre   13  ...  Not pedestrian fault                  Other  Women
# 31   Setembre   29  ...  Not pedestrian fault                    Car    Men
# 39     Juliol   23  ...  Not pedestrian fault             Motorcycle    Men
#
#    Age Person_type                       Pedestrian_accident_location  \
# 6   31      Driver  A la vorera / Andana                          ...
# 8   45      Driver  A la vorera / Andana                          ...
# 17  51      Driver  A la vorera / Andana                          ...
# 31  71      Driver  A la vorera / Andana                          ...
# 39  24      Driver  A la vorera / Andana                          ...
#
#    Pedestrian_intention     Driver_intention Accident_severity  \
# 6            Desconegut  Oci i entreteniment        Assistance
# 8            Desconegut  Oci i entreteniment      Hospitalized
# 17           Desconegut           In itínere      Hospitalized
# 31           Desconegut  Oci i entreteniment        Assistance
# 39           Desconegut    Altres activitats      Hospitalized
#
#                    Date
# 6   2021-06-17 20:00:00
# 8   2021-04-04 10:00:00
# 17  2021-10-13 08:00:00
# 31  2021-09-29 09:00:00
# 39  2021-07-23 19:00:00
#
# [5 rows x 22 columns]

# %%
#FROM ALL THE DATA WE ARE JUST GOING TO FOCUS N¡ON THE DRIVERS BECAUSE
#THE PASSANGER OR THE PEDESTRIAN DOESN0T HAVE ANY KIND OF POWER TO NOT BE IN THE SITUATION OR HAVE ANY CONTROL

persones=persones[['Day_shift','Vehicle_type','Gender','Age','Date']]
weather=weather[['Date','03.TM','06.HRM','10.VVM10']]

#JOIN THE DATASETS WITH THE VARIABLE DATE
variables = pd.merge(persones, weather, on='Date', how='left')
variables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12681 entries, 0 to 12680
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Day_shift     12681 non-null  object
#  1   Vehicle_type  12681 non-null  object
#  2   Gender        12681 non-null  object
#  3   Age           12681 non-null  object
#  4   Date          12681 non-null  object
#  5   03.TM         12681 non-null  float64
#  6   06.HRM        12681 non-null  float64
#  7   10.VVM10      12681 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 891.6+ KB

# %%
#add variable quarter and start studying the different variables
variables['Quarter'] = variables['Date'].apply(lambda x: pd.Timestamp(x).quarter)
variables.head()
# Out:
#    Day_shift           Vehicle_type Gender Age                 Date  03.TM  \
# 0  Afternoon  Vehicle without motor    Men  31  2021-06-17 20:00:00   23.4
# 1    Morning  Vehicle without motor  Women  45  2021-04-04 10:00:00   15.9
# 2    Morning                  Other  Women  51  2021-10-13 08:00:00   19.3
# 3    Morning                    Car    Men  71  2021-09-29 09:00:00   23.5
# 4  Afternoon             Motorcycle    Men  24  2021-07-23 19:00:00   27.7
#
#    06.HRM  10.VVM10  Quarter
# 0    97.0       1.1        2
# 1    55.0       2.3        2
# 2    65.0       1.0        4
# 3    64.0       1.4        3
# 4    53.0       0.8        3

# %%
# LETS TRANSFORM TO CATHEGORIC THE COLUMN EDAT
#'youth' if their age value is lower than 21, 'young adult' from 21 to 31, 'adult' from 32 to 50, 'old' from 51 /// desconegut(404) -->NOT KNOWN
#transform value desconegut a 404
variables['Age'] = variables['Age'].replace('Desconegut', '404')
def categorize_age(age):
    if int(age) <= 23:
        return 'Kid'
    elif int(age) <= 30 and int(age) > 23:
        return 'Youth'
    elif int(age) <= 50 and int(age) > 30:
        return 'Adult'
    elif age == '404':
        return 'Age not known'
    else:
        return 'Old'

# Apply function to transform ages to categories
variables['Age'] = variables['Age'].apply(categorize_age)

x=variables['Age'].unique()
print(x)

# count the frequency of each value in column 'a'
value_counts = variables['Age'].value_counts()

# calculate the percentage of times each value appears
percentage = (value_counts / len(variables)) * 100
print(percentage)
# Out:
# ['Adult' 'Old' 'Youth' 'Kid' 'Age not known']
# Adult            46.266067
# Youth            21.867361
# Old              19.888021
# Kid              11.931236
# Age not known     0.047315
# Name: Age, dtype: float64

# %%
#x=variables['03.TM'].unique()
# print(np.sort(x)) the data goes from 3.8 to 34.2
def cat_temp(temp):
    if int(temp) <= 13:
        return 'Very low'
    elif int(temp) <= 17 and int(temp) > 13:
        return 'Low'
    elif int(temp) <= 24 and int(temp) > 17:
        return 'Mild'
    else:
        return 'Hot'
variables['03.TM'] = variables['03.TM'].apply(cat_temp)

x=variables['03.TM'].unique()
print(x)

# count the frequency of each value in column 'a'
value_counts = variables['03.TM'].value_counts()

# calculate the percentage of times each value appears
percentage = (value_counts / len(variables)) * 100
print(percentage)
# Out:
# ['Mild' 'Low' 'Hot' 'Very low']
# Mild        30.273638
# Very low    25.045343
# Hot         23.200063
# Low         21.480956
# Name: 03.TM, dtype: float64

# %%
#x=variables['06.HRM'].unique()
#print(np.sort(x)) from 9 percent to 100 percent
def cat_humidity(hum):
    if int(hum) <= 48:
        return 'Low humidity'
    elif int(hum) <= 60 and int(hum) > 48:
        return 'Moderate humidity'
    elif int(hum) <= 75 and int(hum) > 60:
        return 'High humidity'
    else:
        return 'Very high'
variables['06.HRM'] = variables['06.HRM'].apply(cat_humidity)

x=variables['06.HRM'].unique()
print(x)

# count the frequency of each value in column 'a'
value_counts = variables['06.HRM'].value_counts()

# calculate the percentage of times each value appears
percentage = (value_counts / len(variables)) * 100
print(percentage)
# Out:
# ['Very high' 'Moderate humidity' 'High humidity' 'Low humidity']
# High humidity        39.216150
# Moderate humidity    25.234603
# Low humidity         19.075783
# Very high            16.473464
# Name: 06.HRM, dtype: float64

# %%
#x=variables['10.VVM10'].unique()
#print(np.sort(x)) from 0 to 8.7
#x=variables['06.HRM'].unique()
#print(np.sort(x)) from 9 percent to 100 percent
def cat_wind(wind):
    if int(wind) <= 1:
        return 'Low speed'
    elif int(wind) <= 2 and int(wind) > 1:
        return 'Moderate speed'
    else:
        return 'High speed'
    
variables['10.VVM10'] = variables['10.VVM10'].apply(cat_wind)

x=variables['10.VVM10'].unique()
print(x)

# count the frequency of each value in column 'a'
value_counts = variables['10.VVM10'].value_counts()

# calculate the percentage of times each value appears
percentage = (value_counts / len(variables)) * 100
print(percentage)
# Out:
# ['Low speed' 'Moderate speed' 'High speed']
# Low speed         43.080199
# Moderate speed    30.344610
# High speed        26.575191
# Name: 10.VVM10, dtype: float64

# %%
from itertools import combinations
from sklearn import preprocessing
from kmodes.kmodes import KModes
# List of variable names
variables_name = ['Day_shift', 'Vehicle_type', 'Gender', 'Age', '03.TM', '06.HRM', '10.VVM10', 'Quarter']

# Generate combinations of 3 to 8 variables
combinations_list = []
for r in range(3, 9):
    combinations_list.extend(combinations(variables_name, r))

# Empty DataFrame to store results
table = pd.DataFrame()

def tuple_to_list(t):
    new_list = []
    for element in t:
        new_list.append(element)
    return new_list

# Iterate over combinations
for selected_columns in combinations_list:
    # Select columns from 'variables' DataFrame based on the combination
    listavar = tuple_to_list(selected_columns)
    subgrup_1 = variables[listavar]

    # Clustering code
    subgroup = subgrup_1.copy()
    from sklearn import preprocessing  
    le = preprocessing.LabelEncoder()
    subgroup_encoded = subgroup.apply(le.fit_transform)
    #to create the list to get the percenge of significant clusters
    l=[]
    # Iterate through cluster numbers
    for n_clusters in range(3, 4):
        # Clustering
        km = KModes(n_clusters=n_clusters, init='Cao', n_init=1, verbose=1)
        clusters = km.fit_predict(subgroup_encoded)

        # Combine with original data
        combined = pd.concat([subgroup.reset_index(), pd.DataFrame({'Cluster': clusters})], axis=1).drop('index', axis=1)

        # Create table
        table = pd.DataFrame(columns=range(n_clusters))

        # Fill in table with percentage of instances of each value in each cluster for each variable
        for var in subgroup.columns:
            by_cluster_value = combined.groupby(['Cluster', var]).size()
            percentages = by_cluster_value.groupby(level=0).apply(lambda x: x / x.sum() * 100)
            pivot_table = pd.pivot_table(percentages.reset_index(), index=var, columns='Cluster', values=0, fill_value=0)

            # Fill in table with percentage of instances for each value in each cluster
            for i, col in enumerate(pivot_table.columns):
                values = pivot_table[col].index.tolist()
                pct_values = pivot_table[col].tolist()
                for j, value in enumerate(values):
                    table.loc[value, i] = pct_values[j]
            # Add new column with variable names based on index
        table['VARIABLE'] = ''

        variable_mapping = {}

        for column in subgroup.columns:
            unique_values = subgroup[column].unique()
            variable_mapping[column] = unique_values

        for i, index_value in enumerate(table.index.values):
            for variable, values in variable_mapping.items():
                if index_value in values:
                    table.iloc[i, -1] = variable
                    break
        print(table)
        print(1)
        table = table.reset_index().rename(columns={'index': 'value'})
        table = table[['VARIABLE'] + list(table.columns[:-1])]
        print(table)
        table = table.set_index('VARIABLE')       

        # Add a new row for the cluster totals
        table.loc['Cluster percentage of drivers'] = 0

        # Calculate the number of instances in each cluster
        cluster_counts = combined['Cluster'].value_counts()

        # Fill in the table with the percentage of instances in each cluster
        for i, count in cluster_counts.items():
            table.loc['Cluster percentage of drivers', i] = count / len(combined) * 100
    
        #table.to_excel(f'table_{n_clusters}_clusters_pas1.xlsx', index=True)
        table1=table
        # Save table to CSV file
        table = table.drop('value', axis=1)
        new_table_2 = pd.DataFrame(index=table.index.unique())
    # Iterate over each column (0, 1, 2, 3) and find the highest percentage for each variable
        for col in table.columns:
            col_max = table.groupby(level=0)[col].max()
            new_table_2[col] = col_max
    # Add the 'Cluster percentage of drivers' row back to the new DataFrame
        new_table_2.loc['Cluster percentage of drivers'] = table.loc['Cluster percentage of drivers']
    # Display the new DataFrame
        #print(new_table_2)
        #new_table_2.to_excel(f'table_{n_clusters}_clusters_pas2.xlsx', index=True)
        new_table_3= new_table_2.loc[new_table_2.index != 'Cluster percentage of drivers'] = (new_table_2.loc[new_table_2.index != 'Cluster percentage of drivers'] >= 75).astype(int)
        new_table_3.loc['number of significant variables'] = new_table_3.sum()
        #new_table_2.to_excel(f'table_{n_clusters}_clusters_pas3.xlsx', index=True)
        #print(new_table_3)  
        new_table_3.loc['Cluster significance'] = new_table_3 .loc['number of significant variables'] / 5
        new_table_3.loc['Cluster significant?'] = new_table_3 .loc['Cluster significance']>=0.5
        new_table_4=new_table_3
        new_table_4.loc['Cluster percentage of drivers'] = table.loc['Cluster percentage of drivers']
        new_table_4.loc['Significant clusters'] = np.nan
    # Add a column with the percentage of significant cluster
        new_table_4.loc['Significant clusters' ,'percentage of significant cluster'] = new_table_4.loc['Cluster significant?'].sum() / n_clusters
    # Transpose the dataframe back to its original orientation
    # Print the resulting dataframe
        #if new_table_4.loc['Cluster significant?'].sum() / n_clusters > 0.7:
        table1.to_excel(f'table_{n_clusters}_clusters_{"".join(selected_columns)}.xlsx', index=True)
    #new_table_4.to_excel(f'table_{n_clusters}_clusters_{"".join(selected_columns)}.xlsx', index=True)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 9581.0
#                                0          1          2      VARIABLE
# Afternoon               68.29421        0.0        0.0     Day_shift
# Morning                22.493479   83.68247  87.207488     Day_shift
# Night                   9.212311   16.31753  12.792512     Day_shift
# Car                      9.03495   16.31753  42.823713  Vehicle_type
# Motorcycle             73.385498   58.76516        0.0  Vehicle_type
# Other                  10.359937   13.39581  36.037441  Vehicle_type
# Vehicle without motor   7.219614  11.521499  21.138846  Vehicle_type
# Men                    78.612415          0        100        Gender
# Not known               0.031299          0          0        Gender
# Women                  21.356286        100          0        Gender
# 1
#        VARIABLE                  value          0          1          2
# 0     Day_shift              Afternoon   68.29421        0.0        0.0
# 1     Day_shift                Morning  22.493479   83.68247  87.207488
# 2     Day_shift                  Night   9.212311   16.31753  12.792512
# 3  Vehicle_type                    Car    9.03495   16.31753  42.823713
# 4  Vehicle_type             Motorcycle  73.385498   58.76516        0.0
# 5  Vehicle_type                  Other  10.359937   13.39581  36.037441
# 6  Vehicle_type  Vehicle without motor   7.219614  11.521499  21.138846
# 7        Gender                    Men  78.612415          0        100
# 8        Gender              Not known   0.031299          0          0
# 9        Gender                  Women  21.356286        100          0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 12183.0
#                                0          1          2      VARIABLE
# Afternoon              74.411731        0.0        0.0     Day_shift
# Morning                16.437422  86.297809  85.810243     Day_shift
# Night                   9.150847  13.702191  14.189757     Day_shift
# Car                     9.844265   5.978463   57.43073  Vehicle_type
# Motorcycle             71.149255  68.362421        0.0  Vehicle_type
# Other                  11.265204  15.187523  25.020991  Vehicle_type
# Vehicle without motor   7.741275  10.471593  17.548279  Vehicle_type
# Adult                  56.667046        0.0  74.055416           Age
# Age not known           0.056838   0.037133        0.0           Age
# Kid                    11.344777  15.818789   7.472712           Age
# Old                    15.380243   35.23951  18.471872           Age
# Youth                  16.551097  48.904567        0.0           Age
# 1
#         VARIABLE                  value          0          1          2
# 0      Day_shift              Afternoon  74.411731        0.0        0.0
# 1      Day_shift                Morning  16.437422  86.297809  85.810243
# 2      Day_shift                  Night   9.150847  13.702191  14.189757
# 3   Vehicle_type                    Car   9.844265   5.978463   57.43073
# 4   Vehicle_type             Motorcycle  71.149255  68.362421        0.0
# 5   Vehicle_type                  Other  11.265204  15.187523  25.020991
# 6   Vehicle_type  Vehicle without motor   7.741275  10.471593  17.548279
# 7            Age                  Adult  56.667046        0.0  74.055416
# 8            Age          Age not known   0.056838   0.037133        0.0
# 9            Age                    Kid  11.344777  15.818789   7.472712
# 10           Age                    Old  15.380243   35.23951  18.471872
# 11           Age                  Youth  16.551097  48.904567        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 13914.0
#                                0          1          2      VARIABLE
# Afternoon              77.928571        0.0          0     Day_shift
# Morning                16.892857  88.090885          0     Day_shift
# Night                   5.178571  11.909115        100     Day_shift
# Car                    13.142857  13.815618  17.256637  Vehicle_type
# Motorcycle             64.154762  63.828676  59.070796  Vehicle_type
# Other                  13.428571  13.214939  14.159292  Vehicle_type
# Vehicle without motor    9.27381   9.140768   9.513274  Vehicle_type
# Hot                    18.595238  30.399582  47.787611         03.TM
# Low                    16.738095  28.258031  52.212389         03.TM
# Mild                   45.702381        0.0        0.0         03.TM
# Very low               18.964286  41.342387        0.0         03.TM
# 1
#         VARIABLE                  value          0          1          2
# 0      Day_shift              Afternoon  77.928571        0.0          0
# 1      Day_shift                Morning  16.892857  88.090885          0
# 2      Day_shift                  Night   5.178571  11.909115        100
# 3   Vehicle_type                    Car  13.142857  13.815618  17.256637
# 4   Vehicle_type             Motorcycle  64.154762  63.828676  59.070796
# 5   Vehicle_type                  Other  13.428571  13.214939  14.159292
# 6   Vehicle_type  Vehicle without motor    9.27381   9.140768   9.513274
# 7          03.TM                    Hot  18.595238  30.399582  47.787611
# 8          03.TM                    Low  16.738095  28.258031  52.212389
# 9          03.TM                   Mild  45.702381        0.0        0.0
# 10         03.TM               Very low  18.964286  41.342387        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 12858.0
#                                0          1          2      VARIABLE
# Afternoon              73.591906        0.0          0     Day_shift
# Morning                20.415964  91.936979          0     Day_shift
# Night                    5.99213   8.063021        100     Day_shift
# Car                    13.479483  12.758727  18.032787  Vehicle_type
# Motorcycle             64.114671  63.762743  60.655738  Vehicle_type
# Other                  13.130972  14.118011  13.296903  Vehicle_type
# Vehicle without motor   9.274874   9.360519   8.014572  Vehicle_type
# High humidity          55.907813        0.0        0.0        06.HRM
# Low humidity           12.445194  36.700649  22.586521        06.HRM
# Moderate humidity      17.807757  49.922768        0.0        06.HRM
# Very high              13.839236  13.376583  77.413479        06.HRM
# 1
#         VARIABLE                  value          0          1          2
# 0      Day_shift              Afternoon  73.591906        0.0          0
# 1      Day_shift                Morning  20.415964  91.936979          0
# 2      Day_shift                  Night    5.99213   8.063021        100
# 3   Vehicle_type                    Car  13.479483  12.758727  18.032787
# 4   Vehicle_type             Motorcycle  64.114671  63.762743  60.655738
# 5   Vehicle_type                  Other  13.130972  14.118011  13.296903
# 6   Vehicle_type  Vehicle without motor   9.274874   9.360519   8.014572
# 7         06.HRM          High humidity  55.907813        0.0        0.0
# 8         06.HRM           Low humidity  12.445194  36.700649  22.586521
# 9         06.HRM      Moderate humidity  17.807757  49.922768        0.0
# 10        06.HRM              Very high  13.839236  13.376583  77.413479
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 13137.0
#                                0          1          2      VARIABLE
# Afternoon              68.724409        0.0          0     Day_shift
# Morning                 19.75853  94.850065          0     Day_shift
# Night                   11.51706   5.149935        100     Day_shift
# Car                    13.511811  13.070404  26.136364  Vehicle_type
# Motorcycle             64.262467  62.940026  54.545455  Vehicle_type
# Other                  13.228346  13.787484  17.045455  Vehicle_type
# Vehicle without motor   8.997375  10.202086   2.272727  Vehicle_type
# High speed             20.209974  44.230769        100      10.VVM10
# Low speed              57.354331        0.0          0      10.VVM10
# Moderate speed         22.435696  55.769231          0      10.VVM10
# 1
#        VARIABLE                  value          0          1          2
# 0     Day_shift              Afternoon  68.724409        0.0          0
# 1     Day_shift                Morning   19.75853  94.850065          0
# 2     Day_shift                  Night   11.51706   5.149935        100
# 3  Vehicle_type                    Car  13.511811  13.070404  26.136364
# 4  Vehicle_type             Motorcycle  64.262467  62.940026  54.545455
# 5  Vehicle_type                  Other  13.228346  13.787484  17.045455
# 6  Vehicle_type  Vehicle without motor   8.997375  10.202086   2.272727
# 7      10.VVM10             High speed  20.209974  44.230769        100
# 8      10.VVM10              Low speed  57.354331        0.0          0
# 9      10.VVM10         Moderate speed  22.435696  55.769231          0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 13944.0
#                                0          1          2      VARIABLE
# Afternoon              79.172714        0.0          0     Day_shift
# Morning                16.243348  91.243386          0     Day_shift
# Night                   4.583938   8.756614        100     Day_shift
# Car                    13.739719  12.671958  15.165877  Vehicle_type
# Motorcycle             64.199323  63.915344  59.399684  Vehicle_type
# Other                  13.098694  13.783069  14.849921  Vehicle_type
# Vehicle without motor   8.962264    9.62963  10.584518  Vehicle_type
# 1                      18.359942  31.693122  37.440758       Quarter
# 2                      21.782777   40.42328        0.0       Quarter
# 3                      18.166425  27.883598  62.559242       Quarter
# 4                      41.690856        0.0        0.0       Quarter
# 1
#         VARIABLE                  value          0          1          2
# 0      Day_shift              Afternoon  79.172714        0.0          0
# 1      Day_shift                Morning  16.243348  91.243386          0
# 2      Day_shift                  Night   4.583938   8.756614        100
# 3   Vehicle_type                    Car  13.739719  12.671958  15.165877
# 4   Vehicle_type             Motorcycle  64.199323  63.915344  59.399684
# 5   Vehicle_type                  Other  13.098694  13.783069  14.849921
# 6   Vehicle_type  Vehicle without motor   8.962264    9.62963  10.584518
# 7        Quarter                      1  18.359942  31.693122  37.440758
# 8        Quarter                      2  21.782777   40.42328        0.0
# 9        Quarter                      3  18.166425  27.883598  62.559242
# 10       Quarter                      4  41.690856        0.0        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 10602.0
#                        0          1          2   VARIABLE
# Afternoon       70.50175  18.234443        0.0  Day_shift
# Morning        17.281214  75.832127  90.200445  Day_shift
# Night          12.217036    5.93343   9.799555  Day_shift
# Men             80.42007  20.911722        100     Gender
# Not known       0.035006        0.0          0     Gender
# Women          19.544924  79.088278          0     Gender
# Adult          59.684947  27.206946        0.0        Age
# Age not known   0.046674   0.036179   0.074239        Age
# Kid            11.540257   6.837916  24.870082        Age
# Old            14.305718  10.311143  75.055679        Age
# Youth          14.422404  55.607815        0.0        Age
# 1
#      VARIABLE          value          0          1          2
# 0   Day_shift      Afternoon   70.50175  18.234443        0.0
# 1   Day_shift        Morning  17.281214  75.832127  90.200445
# 2   Day_shift          Night  12.217036    5.93343   9.799555
# 3      Gender            Men   80.42007  20.911722        100
# 4      Gender      Not known   0.035006        0.0          0
# 5      Gender          Women  19.544924  79.088278          0
# 6         Age          Adult  59.684947  27.206946        0.0
# 7         Age  Age not known   0.046674   0.036179   0.074239
# 8         Age            Kid  11.540257   6.837916  24.870082
# 9         Age            Old  14.305718  10.311143  75.055679
# 10        Age          Youth  14.422404  55.607815        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 11773.0
#                    0          1          2   VARIABLE
# Afternoon  75.711956  17.240216        0.0  Day_shift
# Morning    12.006022   76.11336  90.435281  Day_shift
# Night      12.282022   6.646424   9.564719  Day_shift
# Men        79.450508  24.898785        100     Gender
# Not known   0.025091   0.033738          0     Gender
# Women      20.524401  75.067476          0     Gender
# Hot        19.596036  13.495277  56.128293      03.TM
# Low        20.010036  12.246964  43.871707      03.TM
# Mild       42.366077  15.587045        0.0      03.TM
# Very low   18.027851  58.670715        0.0      03.TM
# 1
#     VARIABLE      value          0          1          2
# 0  Day_shift  Afternoon  75.711956  17.240216        0.0
# 1  Day_shift    Morning  12.006022   76.11336  90.435281
# 2  Day_shift      Night  12.282022   6.646424   9.564719
# 3     Gender        Men  79.450508  24.898785        100
# 4     Gender  Not known   0.025091   0.033738          0
# 5     Gender      Women  20.524401  75.067476          0
# 6      03.TM        Hot  19.596036  13.495277  56.128293
# 7      03.TM        Low  20.010036  12.246964  43.871707
# 8      03.TM       Mild  42.366077  15.587045        0.0
# 9      03.TM   Very low  18.027851  58.670715        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 11153.0
#                            0          1          2   VARIABLE
# Afternoon          72.521449  14.964216        0.0  Day_shift
# Morning            14.823642  79.212752  91.604938  Day_shift
# Night              12.654909   5.823032   8.395062  Day_shift
# Men                79.659199  29.830839        100     Gender
# Not known           0.035748        0.0          0     Gender
# Women              20.305052  70.169161          0     Gender
# High humidity      52.442803  18.607677        0.0     06.HRM
# Low humidity       13.191134   12.58946  76.131687     06.HRM
# Moderate humidity  15.812679  60.930384        0.0     06.HRM
# Very high          18.553384   7.872479  23.868313     06.HRM
# 1
#     VARIABLE              value          0          1          2
# 0  Day_shift          Afternoon  72.521449  14.964216        0.0
# 1  Day_shift            Morning  14.823642  79.212752  91.604938
# 2  Day_shift              Night  12.654909   5.823032   8.395062
# 3     Gender                Men  79.659199  29.830839        100
# 4     Gender          Not known   0.035748        0.0          0
# 5     Gender              Women  20.305052  70.169161          0
# 6     06.HRM      High humidity  52.442803  18.607677        0.0
# 7     06.HRM       Low humidity  13.191134   12.58946  76.131687
# 8     06.HRM  Moderate humidity  15.812679  60.930384        0.0
# 9     06.HRM          Very high  18.553384   7.872479  23.868313
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 10513.0
#                         0          1          2   VARIABLE
# Afternoon       70.797738   19.87988        0.0  Day_shift
# Morning         14.643244  78.228228  93.269231  Day_shift
# Night           14.559018   1.891892   6.730769  Day_shift
# Men             80.495729  32.642643        100     Gender
# Not known        0.036097        0.0          0     Gender
# Women           19.468175  67.357357          0     Gender
# High speed      23.162074  12.162162        100   10.VVM10
# Low speed       57.730718   19.96997          0   10.VVM10
# Moderate speed  19.107207  67.867868          0   10.VVM10
# 1
#     VARIABLE           value          0          1          2
# 0  Day_shift       Afternoon  70.797738   19.87988        0.0
# 1  Day_shift         Morning  14.643244  78.228228  93.269231
# 2  Day_shift           Night  14.559018   1.891892   6.730769
# 3     Gender             Men  80.495729  32.642643        100
# 4     Gender       Not known   0.036097        0.0          0
# 5     Gender           Women  19.468175  67.357357          0
# 6   10.VVM10      High speed  23.162074  12.162162        100
# 7   10.VVM10       Low speed  57.730718   19.96997          0
# 8   10.VVM10  Moderate speed  19.107207  67.867868          0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 12068.0
#                    0          1          2   VARIABLE
# Afternoon  76.696919  17.612903        0.0  Day_shift
# Morning     11.10827  75.870968  89.362912  Day_shift
# Night       12.19481   6.516129  10.637088  Day_shift
# Men        79.573054  26.903226        100     Gender
# Not known   0.038348        0.0          0     Gender
# Women      20.388598  73.096774          0     Gender
# 1          19.404321  13.483871  57.849829    Quarter
# 2          19.378755  58.483871        0.0    Quarter
# 3          23.213601  12.741935  42.150171    Quarter
# 4          38.003324  15.290323        0.0    Quarter
# 1
#     VARIABLE      value          0          1          2
# 0  Day_shift  Afternoon  76.696919  17.612903        0.0
# 1  Day_shift    Morning   11.10827  75.870968  89.362912
# 2  Day_shift      Night   12.19481   6.516129  10.637088
# 3     Gender        Men  79.573054  26.903226        100
# 4     Gender  Not known   0.038348        0.0          0
# 5     Gender      Women  20.388598  73.096774          0
# 6    Quarter          1  19.404321  13.483871  57.849829
# 7    Quarter          2  19.378755  58.483871        0.0
# 8    Quarter          3  23.213601  12.741935  42.150171
# 9    Quarter          4  38.003324  15.290323        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14912.0
#                        0          1          2   VARIABLE
# Afternoon      75.935763  13.194444        0.0  Day_shift
# Morning        13.934527  74.470899  90.396927  Day_shift
# Night           10.12971  12.334656   9.603073  Day_shift
# Adult          51.785053  18.584656  71.254802        Age
# Age not known   0.061767   0.033069        0.0        Age
# Kid            13.353922    9.52381    9.21895        Age
# Old            20.382952      18.75  19.526248        Age
# Youth          14.416306  53.108466        0.0        Age
# Hot            19.295862   9.589947   69.78233      03.TM
# Low            19.518221  22.222222   30.21767      03.TM
# Mild           43.829524   9.623016        0.0      03.TM
# Very low       17.356393  58.564815        0.0      03.TM
# 1
#      VARIABLE          value          0          1          2
# 0   Day_shift      Afternoon  75.935763  13.194444        0.0
# 1   Day_shift        Morning  13.934527  74.470899  90.396927
# 2   Day_shift          Night   10.12971  12.334656   9.603073
# 3         Age          Adult  51.785053  18.584656  71.254802
# 4         Age  Age not known   0.061767   0.033069        0.0
# 5         Age            Kid  13.353922    9.52381    9.21895
# 6         Age            Old  20.382952      18.75  19.526248
# 7         Age          Youth  14.416306  53.108466        0.0
# 8       03.TM            Hot  19.295862   9.589947   69.78233
# 9       03.TM            Low  19.518221  22.222222   30.21767
# 10      03.TM           Mild  43.829524   9.623016        0.0
# 11      03.TM       Very low  17.356393  58.564815        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14201.0
#                            0          1          2   VARIABLE
# Afternoon           71.99767  12.957047        0.0  Day_shift
# Morning            16.773442  76.819311  92.885066  Day_shift
# Night              11.228888  10.223642   7.114934  Day_shift
# Adult              51.426907  21.796237  65.519937        Age
# Age not known       0.046593   0.070998        0.0        Age
# Kid                13.453698   7.596734  11.258796        Age
# Old                20.512522  16.471424  23.221267        Age
# Youth               14.56028  54.064608        0.0        Age
# High humidity      53.546884  13.347533        0.0     06.HRM
# Low humidity       12.894584   8.519702  83.815481     06.HRM
# Moderate humidity  15.562027  66.169684        0.0     06.HRM
# Very high          17.996506  11.963081  16.184519     06.HRM
# 1
#      VARIABLE              value          0          1          2
# 0   Day_shift          Afternoon   71.99767  12.957047        0.0
# 1   Day_shift            Morning  16.773442  76.819311  92.885066
# 2   Day_shift              Night  11.228888  10.223642   7.114934
# 3         Age              Adult  51.426907  21.796237  65.519937
# 4         Age      Age not known   0.046593   0.070998        0.0
# 5         Age                Kid  13.453698   7.596734  11.258796
# 6         Age                Old  20.512522  16.471424  23.221267
# 7         Age              Youth   14.56028  54.064608        0.0
# 8      06.HRM      High humidity  53.546884  13.347533        0.0
# 9      06.HRM       Low humidity  12.894584   8.519702  83.815481
# 10     06.HRM  Moderate humidity  15.562027  66.169684        0.0
# 11     06.HRM          Very high  17.996506  11.963081  16.184519
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 13679.0
#                         0          1          2   VARIABLE
# Afternoon        69.69905  16.503446        0.0  Day_shift
# Morning         16.958462   79.50671  94.345992  Day_shift
# Night           13.342488   3.989844   5.654008  Day_shift
# Adult           51.184346  26.260428  56.540084        Age
# Age not known    0.045772   0.036271   0.084388        Age
# Kid             13.559904    5.80341  14.177215        Age
# Old              20.35702   14.39971  29.198312        Age
# Youth           14.852958  53.500181        0.0        Age
# High speed      22.027692    9.43054        100   10.VVM10
# Low speed       57.935691  14.508524          0   10.VVM10
# Moderate speed  20.036617  76.060936          0   10.VVM10
# 1
#      VARIABLE           value          0          1          2
# 0   Day_shift       Afternoon   69.69905  16.503446        0.0
# 1   Day_shift         Morning  16.958462   79.50671  94.345992
# 2   Day_shift           Night  13.342488   3.989844   5.654008
# 3         Age           Adult  51.184346  26.260428  56.540084
# 4         Age   Age not known   0.045772   0.036271   0.084388
# 5         Age             Kid  13.559904    5.80341  14.177215
# 6         Age             Old   20.35702   14.39971  29.198312
# 7         Age           Youth  14.852958  53.500181        0.0
# 8    10.VVM10      High speed  22.027692    9.43054        100
# 9    10.VVM10       Low speed  57.935691  14.508524          0
# 10   10.VVM10  Moderate speed  20.036617  76.060936          0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15138.0
#                        0          1          2   VARIABLE
# Afternoon      76.497639   12.99867        0.0  Day_shift
# Morning        13.435247  74.700798  89.981561  Day_shift
# Night          10.067114  12.300532  10.018439  Day_shift
# Adult          51.503853   18.25133  72.157345        Age
# Age not known   0.049714   0.066489        0.0        Age
# Kid            13.373105   9.574468   9.157959        Age
# Old            20.618941  18.583777  18.684696        Age
# Youth          14.454387  53.523936        0.0        Age
# 1              18.866518   9.441489    70.7437    Quarter
# 2              19.313945  59.009309        0.0    Quarter
# 3              22.234651  22.839096    29.2563    Quarter
# 4              39.584887   8.710106        0.0    Quarter
# 1
#      VARIABLE          value          0          1          2
# 0   Day_shift      Afternoon  76.497639   12.99867        0.0
# 1   Day_shift        Morning  13.435247  74.700798  89.981561
# 2   Day_shift          Night  10.067114  12.300532  10.018439
# 3         Age          Adult  51.503853   18.25133  72.157345
# 4         Age  Age not known   0.049714   0.066489        0.0
# 5         Age            Kid  13.373105   9.574468   9.157959
# 6         Age            Old  20.618941  18.583777  18.684696
# 7         Age          Youth  14.454387  53.523936        0.0
# 8     Quarter              1  18.866518   9.441489    70.7437
# 9     Quarter              2  19.313945  59.009309        0.0
# 10    Quarter              3  22.234651  22.839096    29.2563
# 11    Quarter              4  39.584887   8.710106        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15446.0
#                            0          1          2   VARIABLE
# Afternoon          77.822328  10.216529        0.0  Day_shift
# Morning            12.141336  78.164074  88.669951  Day_shift
# Night              10.036336  11.619396  11.330049  Day_shift
# Hot                19.571482  12.412321  68.472906      03.TM
# Low                20.047613  20.616041  31.527094      03.TM
# Mild                42.46335  13.723696        0.0      03.TM
# Very low           17.917554  53.247941        0.0      03.TM
# High humidity      45.495552  12.076853  66.572836     06.HRM
# Low humidity       18.356096  16.224459  29.697396     06.HRM
# Moderate humidity   16.56434  57.273559        0.0     06.HRM
# Very high          19.584012   14.42513   3.729768     06.HRM
# 1
#      VARIABLE              value          0          1          2
# 0   Day_shift          Afternoon  77.822328  10.216529        0.0
# 1   Day_shift            Morning  12.141336  78.164074  88.669951
# 2   Day_shift              Night  10.036336  11.619396  11.330049
# 3       03.TM                Hot  19.571482  12.412321  68.472906
# 4       03.TM                Low  20.047613  20.616041  31.527094
# 5       03.TM               Mild   42.46335  13.723696        0.0
# 6       03.TM           Very low  17.917554  53.247941        0.0
# 7      06.HRM      High humidity  45.495552  12.076853  66.572836
# 8      06.HRM       Low humidity  18.356096  16.224459  29.697396
# 9      06.HRM  Moderate humidity   16.56434  57.273559        0.0
# 10     06.HRM          Very high  19.584012   14.42513   3.729768
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14538.0
#                         0          1          2   VARIABLE
# Afternoon       61.308618  12.287234  97.635934  Day_shift
# Morning          22.28524  84.601064        0.0  Day_shift
# Night           16.406142   3.111702   2.364066  Day_shift
# Hot             10.513211  24.707447  74.054374      03.TM
# Low              22.28524  17.925532  25.945626      03.TM
# Mild            46.562457  12.579787        0.0      03.TM
# Very low        20.639093  44.787234        0.0      03.TM
# High speed      24.152718  26.329787  37.470449   10.VVM10
# Low speed       66.205561  18.005319        0.0   10.VVM10
# Moderate speed   9.641721  55.664894  62.529551   10.VVM10
# 1
#     VARIABLE           value          0          1          2
# 0  Day_shift       Afternoon  61.308618  12.287234  97.635934
# 1  Day_shift         Morning   22.28524  84.601064        0.0
# 2  Day_shift           Night  16.406142   3.111702   2.364066
# 3      03.TM             Hot  10.513211  24.707447  74.054374
# 4      03.TM             Low   22.28524  17.925532  25.945626
# 5      03.TM            Mild  46.562457  12.579787        0.0
# 6      03.TM        Very low  20.639093  44.787234        0.0
# 7   10.VVM10      High speed  24.152718  26.329787  37.470449
# 8   10.VVM10       Low speed  66.205561  18.005319        0.0
# 9   10.VVM10  Moderate speed   9.641721  55.664894  62.529551
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1269, cost: 15402.0
#                    0          1          2   VARIABLE
# Afternoon  68.029471      7.859  68.102698  Day_shift
# Morning    21.453337  79.456804  24.238468  Day_shift
# Night      10.517192  12.684195   7.658834  Day_shift
# Hot         6.038717  14.244438  88.381201      03.TM
# Low        25.657324  24.270442   4.699739      03.TM
# Mild       49.234325  12.453048        0.0      03.TM
# Very low   19.069633  49.032072    6.91906      03.TM
# 1          23.865935    34.4987   4.656223    Quarter
# 2           17.59607   48.16527  19.321149    Quarter
# 3          14.229991   6.356544  76.022628    Quarter
# 4          44.308003  10.979486        0.0    Quarter
# 1
#      VARIABLE      value          0          1          2
# 0   Day_shift  Afternoon  68.029471      7.859  68.102698
# 1   Day_shift    Morning  21.453337  79.456804  24.238468
# 2   Day_shift      Night  10.517192  12.684195   7.658834
# 3       03.TM        Hot   6.038717  14.244438  88.381201
# 4       03.TM        Low  25.657324  24.270442   4.699739
# 5       03.TM       Mild  49.234325  12.453048        0.0
# 6       03.TM   Very low  19.069633  49.032072    6.91906
# 7     Quarter          1  23.865935    34.4987   4.656223
# 8     Quarter          2   17.59607   48.16527  19.321149
# 9     Quarter          3  14.229991   6.356544  76.022628
# 10    Quarter          4  44.308003  10.979486        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14122.0
#                            0          1          2   VARIABLE
# Afternoon           70.54073  16.790683        0.0  Day_shift
# Morning            15.941011  79.003559  94.455067  Day_shift
# Night              13.518258   4.205759   5.544933  Day_shift
# High humidity      45.201311  19.475898  48.661568     06.HRM
# Low humidity       18.387172  13.458428  41.300191     06.HRM
# Moderate humidity  14.840824  62.504044        0.0     06.HRM
# Very high          21.570693   4.561631  10.038241     06.HRM
# High speed         22.530431  12.908444        100   10.VVM10
# Low speed          57.853464  16.823035          0   10.VVM10
# Moderate speed     19.616105  70.268522          0   10.VVM10
# 1
#     VARIABLE              value          0          1          2
# 0  Day_shift          Afternoon   70.54073  16.790683        0.0
# 1  Day_shift            Morning  15.941011  79.003559  94.455067
# 2  Day_shift              Night  13.518258   4.205759   5.544933
# 3     06.HRM      High humidity  45.201311  19.475898  48.661568
# 4     06.HRM       Low humidity  18.387172  13.458428  41.300191
# 5     06.HRM  Moderate humidity  14.840824  62.504044        0.0
# 6     06.HRM          Very high  21.570693   4.561631  10.038241
# 7   10.VVM10         High speed  22.530431  12.908444        100
# 8   10.VVM10          Low speed  57.853464  16.823035          0
# 9   10.VVM10     Moderate speed  19.616105  70.268522          0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 15637.0
#                            0          1          2   VARIABLE
# Afternoon          76.979417  13.452915        0.0  Day_shift
# Morning            12.678368   76.32287  87.155963  Day_shift
# Night              10.342215  10.224215  12.844037  Day_shift
# High humidity      46.382119  13.751868  59.280169     06.HRM
# Low humidity       17.426443  19.970105  26.182075     06.HRM
# Moderate humidity  15.102917  59.910314        0.0     06.HRM
# Very high          21.088521   6.367713  14.537756     06.HRM
# 1                  19.169087  11.958146  73.041637    Quarter
# 2                  18.525066  55.665172        0.0    Quarter
# 3                  23.058467  22.242152  26.958363    Quarter
# 4                   39.24738  10.134529        0.0    Quarter
# 1
#      VARIABLE              value          0          1          2
# 0   Day_shift          Afternoon  76.979417  13.452915        0.0
# 1   Day_shift            Morning  12.678368   76.32287  87.155963
# 2   Day_shift              Night  10.342215  10.224215  12.844037
# 3      06.HRM      High humidity  46.382119  13.751868  59.280169
# 4      06.HRM       Low humidity  17.426443  19.970105  26.182075
# 5      06.HRM  Moderate humidity  15.102917  59.910314        0.0
# 6      06.HRM          Very high  21.088521   6.367713  14.537756
# 7     Quarter                  1  19.169087  11.958146  73.041637
# 8     Quarter                  2  18.525066  55.665172        0.0
# 9     Quarter                  3  23.058467  22.242152  26.958363
# 10    Quarter                  4   39.24738  10.134529        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14610.0
#                         0          1          2   VARIABLE
# Afternoon       59.817289  17.142102  96.732864  Day_shift
# Morning         24.202345  79.688325        0.0  Day_shift
# Night           15.980365   3.169572   3.267136  Day_shift
# High speed      23.275157  30.744849  31.966688   10.VVM10
# Low speed       70.016362   8.663497        0.0   10.VVM10
# Moderate speed   6.708481  60.591653  68.033312   10.VVM10
# 1               16.607581  18.304279  66.752082    Quarter
# 2                19.23916  50.660328        0.0    Quarter
# 3               22.320698  21.024828  33.247918    Quarter
# 4               41.832561  10.010565        0.0    Quarter
# 1
#     VARIABLE           value          0          1          2
# 0  Day_shift       Afternoon  59.817289  17.142102  96.732864
# 1  Day_shift         Morning  24.202345  79.688325        0.0
# 2  Day_shift           Night  15.980365   3.169572   3.267136
# 3   10.VVM10      High speed  23.275157  30.744849  31.966688
# 4   10.VVM10       Low speed  70.016362   8.663497        0.0
# 5   10.VVM10  Moderate speed   6.708481  60.591653  68.033312
# 6    Quarter               1  16.607581  18.304279  66.752082
# 7    Quarter               2   19.23916  50.660328        0.0
# 8    Quarter               3  22.320698  21.024828  33.247918
# 9    Quarter               4  41.832561  10.010565        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 11114.0
#                                0          1          2      VARIABLE
# Car                     8.030178  17.224409  60.020555  Vehicle_type
# Motorcycle             71.785862  56.791339        0.0  Vehicle_type
# Other                  11.988425  15.009843  23.946557  Vehicle_type
# Vehicle without motor   8.195535  10.974409  16.032888  Vehicle_type
# Men                    81.076891          0  99.897225        Gender
# Not known                0.02067          0   0.102775        Gender
# Women                  18.902439        100        0.0        Gender
# Adult                   60.63456        0.0        0.0           Age
# Age not known           0.041339   0.049213   0.102775           Age
# Kid                    10.024804  21.948819   9.969168           Age
# Old                    16.442745  30.807087  31.346351           Age
# Youth                  12.856552  47.194882  58.581706           Age
# 1
#         VARIABLE                  value          0          1          2
# 0   Vehicle_type                    Car   8.030178  17.224409  60.020555
# 1   Vehicle_type             Motorcycle  71.785862  56.791339        0.0
# 2   Vehicle_type                  Other  11.988425  15.009843  23.946557
# 3   Vehicle_type  Vehicle without motor   8.195535  10.974409  16.032888
# 4         Gender                    Men  81.076891          0  99.897225
# 5         Gender              Not known    0.02067          0   0.102775
# 6         Gender                  Women  18.902439        100        0.0
# 7            Age                  Adult   60.63456        0.0        0.0
# 8            Age          Age not known   0.041339   0.049213   0.102775
# 9            Age                    Kid  10.024804  21.948819   9.969168
# 10           Age                    Old  16.442745  30.807087  31.346351
# 11           Age                  Youth  12.856552  47.194882  58.581706
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 12180.0
#                                0          1          2      VARIABLE
# Car                     5.902268  17.357223  63.365469  Vehicle_type
# Motorcycle             73.761426  58.379993        0.0  Vehicle_type
# Other                  12.289809  13.251213  22.261174  Vehicle_type
# Vehicle without motor   8.046496  11.011571  14.373357  Vehicle_type
# Men                    86.638077        0.0  99.912358        Gender
# Not known               0.011285   0.037327   0.087642        Gender
# Women                  13.350638  99.962673        0.0        Gender
# Hot                    20.753865   32.96006  19.281332         03.TM
# Low                    19.331904  29.675252  18.930762         03.TM
# Mild                   43.324681        0.0        0.0         03.TM
# Very low                16.58955  37.364688  61.787905         03.TM
# 1
#         VARIABLE                  value          0          1          2
# 0   Vehicle_type                    Car   5.902268  17.357223  63.365469
# 1   Vehicle_type             Motorcycle  73.761426  58.379993        0.0
# 2   Vehicle_type                  Other  12.289809  13.251213  22.261174
# 3   Vehicle_type  Vehicle without motor   8.046496  11.011571  14.373357
# 4         Gender                    Men  86.638077        0.0  99.912358
# 5         Gender              Not known   0.011285   0.037327   0.087642
# 6         Gender                  Women  13.350638  99.962673        0.0
# 7          03.TM                    Hot  20.753865   32.96006  19.281332
# 8          03.TM                    Low  19.331904  29.675252  18.930762
# 9          03.TM                   Mild  43.324681        0.0        0.0
# 10         03.TM               Very low   16.58955  37.364688  61.787905
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 11460.0
#                                0          1          2      VARIABLE
# Car                     7.355498  16.809605  56.069869  Vehicle_type
# Motorcycle             73.392003  57.675815        0.0  Vehicle_type
# Other                   11.64711  14.022298  26.113537  Vehicle_type
# Vehicle without motor   7.605389  11.492281  17.816594  Vehicle_type
# Men                    83.365928          0  99.912664        Gender
# Not known                0.02173          0   0.087336        Gender
# Women                  16.612342        100        0.0        Gender
# High humidity          54.030856        0.0        0.0        06.HRM
# Low humidity           16.210343  31.217839  17.379913        06.HRM
# Moderate humidity       16.09083  40.994854  66.637555        06.HRM
# Very high               13.66797  27.787307  15.982533        06.HRM
# 1
#         VARIABLE                  value          0          1          2
# 0   Vehicle_type                    Car   7.355498  16.809605  56.069869
# 1   Vehicle_type             Motorcycle  73.392003  57.675815        0.0
# 2   Vehicle_type                  Other   11.64711  14.022298  26.113537
# 3   Vehicle_type  Vehicle without motor   7.605389  11.492281  17.816594
# 4         Gender                    Men  83.365928          0  99.912664
# 5         Gender              Not known    0.02173          0   0.087336
# 6         Gender                  Women  16.612342        100        0.0
# 7         06.HRM          High humidity  54.030856        0.0        0.0
# 8         06.HRM           Low humidity  16.210343  31.217839  17.379913
# 9         06.HRM      Moderate humidity   16.09083  40.994854  66.637555
# 10        06.HRM              Very high   13.66797  27.787307  15.982533
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 10853.0
#                                0          1          2      VARIABLE
# Car                      7.88657  18.227732  49.827288  Vehicle_type
# Motorcycle             73.504548  56.519743        0.0  Vehicle_type
# Other                  11.300161  13.865932  29.360967  Vehicle_type
# Vehicle without motor   7.308721  11.386593  20.811744  Vehicle_type
# Men                    81.968967          0  99.913644        Gender
# Not known               0.021402          0   0.086356        Gender
# Women                  18.009631        100        0.0        Gender
# High speed               22.3542  46.143251  23.834197      10.VVM10
# Low speed              58.459069        0.0        0.0      10.VVM10
# Moderate speed         19.186731  53.856749  76.165803      10.VVM10
# 1
#        VARIABLE                  value          0          1          2
# 0  Vehicle_type                    Car    7.88657  18.227732  49.827288
# 1  Vehicle_type             Motorcycle  73.504548  56.519743        0.0
# 2  Vehicle_type                  Other  11.300161  13.865932  29.360967
# 3  Vehicle_type  Vehicle without motor   7.308721  11.386593  20.811744
# 4        Gender                    Men  81.968967          0  99.913644
# 5        Gender              Not known   0.021402          0   0.086356
# 6        Gender                  Women  18.009631        100        0.0
# 7      10.VVM10             High speed    22.3542  46.143251  23.834197
# 8      10.VVM10              Low speed  58.459069        0.0        0.0
# 9      10.VVM10         Moderate speed  19.186731  53.856749  76.165803
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 12439.0
#                                0          1          2      VARIABLE
# Car                     5.788262  16.911765  58.851298  Vehicle_type
# Motorcycle             75.235903  57.426471        0.0  Vehicle_type
# Other                  11.588032      13.75  24.940991  Vehicle_type
# Vehicle without motor   7.387802  11.911765   16.20771  Vehicle_type
# Men                    86.846951          0  99.921322        Gender
# Not known               0.023015          0   0.078678        Gender
# Women                  13.130035        100        0.0        Gender
# 1                      20.955121  32.279412  19.984264       Quarter
# 2                      17.917146  35.992647  62.391817       Quarter
# 3                       21.46145  31.727941  17.623918       Quarter
# 4                      39.666283        0.0        0.0       Quarter
# 1
#         VARIABLE                  value          0          1          2
# 0   Vehicle_type                    Car   5.788262  16.911765  58.851298
# 1   Vehicle_type             Motorcycle  75.235903  57.426471        0.0
# 2   Vehicle_type                  Other  11.588032      13.75  24.940991
# 3   Vehicle_type  Vehicle without motor   7.387802  11.911765   16.20771
# 4         Gender                    Men  86.846951          0  99.921322
# 5         Gender              Not known   0.023015          0   0.078678
# 6         Gender                  Women  13.130035        100        0.0
# 7        Quarter                      1  20.955121  32.279412  19.984264
# 8        Quarter                      2  17.917146  35.992647  62.391817
# 9        Quarter                      3   21.46145  31.727941  17.623918
# 10       Quarter                      4  39.666283        0.0        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 14470.0
#                                0          1          2      VARIABLE
# Car                    13.285112  13.133077  15.298752  Vehicle_type
# Motorcycle             63.918023  64.338107  62.770847  Vehicle_type
# Other                  13.321278  13.657003  13.263296  Vehicle_type
# Vehicle without motor   9.475588   8.871813   8.667104  Vehicle_type
# Adult                  70.729355        0.0        0.0           Age
# Age not known           0.036166   0.034928    0.13132           Age
# Kid                     9.969861  12.364652  21.799081           Age
# Old                     9.138035  20.083828  78.069599           Age
# Youth                  10.126582  67.516591        0.0           Age
# Hot                    16.793249  20.537897  63.099146         03.TM
# Low                     18.93912  20.642683  36.900854         03.TM
# Mild                   46.280892        0.0        0.0         03.TM
# Very low               17.986739   58.81942        0.0         03.TM
# 1
#         VARIABLE                  value          0          1          2
# 0   Vehicle_type                    Car  13.285112  13.133077  15.298752
# 1   Vehicle_type             Motorcycle  63.918023  64.338107  62.770847
# 2   Vehicle_type                  Other  13.321278  13.657003  13.263296
# 3   Vehicle_type  Vehicle without motor   9.475588   8.871813   8.667104
# 4            Age                  Adult  70.729355        0.0        0.0
# 5            Age          Age not known   0.036166   0.034928    0.13132
# 6            Age                    Kid   9.969861  12.364652  21.799081
# 7            Age                    Old   9.138035  20.083828  78.069599
# 8            Age                  Youth  10.126582  67.516591        0.0
# 9          03.TM                    Hot  16.793249  20.537897  63.099146
# 10         03.TM                    Low   18.93912  20.642683  36.900854
# 11         03.TM                   Mild  46.280892        0.0        0.0
# 12         03.TM               Very low  17.986739   58.81942        0.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 13978.0
#                                0          1          2      VARIABLE
# Car                    13.468551  12.179017  16.709075  Vehicle_type
# Motorcycle              63.87876  64.453412  62.510602  Vehicle_type
# Other                  13.457156  13.462949  12.722646  Vehicle_type
# Vehicle without motor   9.195533   9.904622   8.057676  Vehicle_type
# Adult                   66.85278        0.0        0.0           Age
# Age not known           0.022789   0.146735        0.0           Age
# Kid                     9.594348  13.939839  24.681934           Age
# Old                    11.064266   24.32135  75.318066           Age
# Youth                  12.465816  61.592076        0.0           Age
# High humidity          56.665907        0.0        0.0        06.HRM
# Low humidity           12.830447  17.901687  68.278202        06.HRM
# Moderate humidity      16.488149  64.306676        0.0        06.HRM
# Very high              14.015497  17.791636  31.721798        06.HRM
# 1
#         VARIABLE                  value          0          1          2
# 0   Vehicle_type                    Car  13.468551  12.179017  16.709075
# 1   Vehicle_type             Motorcycle   63.87876  64.453412  62.510602
# 2   Vehicle_type                  Other  13.457156  13.462949  12.722646
# 3   Vehicle_type  Vehicle without motor   9.195533   9.904622   8.057676
# 4            Age                  Adult   66.85278        0.0        0.0
# 5            Age          Age not known   0.022789   0.146735        0.0
# 6            Age                    Kid   9.594348  13.939839  24.681934
# 7            Age                    Old  11.064266   24.32135  75.318066
# 8            Age                  Youth  12.465816  61.592076        0.0
# 9         06.HRM          High humidity  56.665907        0.0        0.0
# 10        06.HRM           Low humidity  12.830447  17.901687  68.278202
# 11        06.HRM      Moderate humidity  16.488149  64.306676        0.0
# 12        06.HRM              Very high  14.015497  17.791636  31.721798
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 13243.0
#                                0          1          2      VARIABLE
# Car                    13.389831  13.203384  15.017986  Vehicle_type
# Motorcycle              64.40678  63.037882  61.690647  Vehicle_type
# Other                  13.073446   13.90217  14.658273  Vehicle_type
# Vehicle without motor   9.129944   9.856565   8.633094  Vehicle_type
# Adult                  66.293785        0.0        0.0           Age
# ...
# Night                  13.604101   7.983959   3.819742     Day_shift
# Car                    14.064143  11.848341  13.562232  Vehicle_type
# Motorcycle             63.985279  63.580022  63.862661  Vehicle_type
# Other                  13.157203  14.363835  13.004292  Vehicle_type
# Vehicle without motor   8.793375  10.207802   9.570815  Vehicle_type
# Adult                  51.314406  20.670798  59.914163           Age
# Age not known           0.026288   0.109369   0.042918           Age
# Kid                    12.723449  10.754648  10.729614           Age
# Old                    18.533123  23.550857       20.0           Age
# Youth                  17.402734  44.914327   9.313305           Age
# Hot                    14.839642  22.748815  51.030043         03.TM
# Low                     21.37224  20.087495  23.476395         03.TM
# Mild                   40.431125  18.045935  11.502146         03.TM
# Very low               23.356993  39.117754  13.991416         03.TM
# High humidity          53.575184  18.410499  16.824034        06.HRM
# Low humidity            9.187697   14.61903  56.609442        06.HRM
# Moderate humidity      16.863828   53.99198  18.712446        06.HRM
# Very high              20.373291  12.978491   7.854077        06.HRM
# High speed             17.626183  17.207437  66.824034      10.VVM10
# Low speed              58.740799  23.587313  14.892704      10.VVM10
# Moderate speed         23.633018   59.20525  18.283262      10.VVM10
# 1                      16.876972  24.899745  42.317597       Quarter
# 2                      21.832282  44.877871  18.755365       Quarter
# 3                       22.69979  18.993802  30.214592       Quarter
# 4                      38.590957  11.228582   8.712446       Quarter
# 1
#         VARIABLE                  value          0          1          2
# 0      Day_shift              Afternoon  65.786015  29.310973  31.630901
# 1      Day_shift                Morning  20.609884  62.705067  64.549356
# 2      Day_shift                  Night  13.604101   7.983959   3.819742
# 3   Vehicle_type                    Car  14.064143  11.848341  13.562232
# 4   Vehicle_type             Motorcycle  63.985279  63.580022  63.862661
# 5   Vehicle_type                  Other  13.157203  14.363835  13.004292
# 6   Vehicle_type  Vehicle without motor   8.793375  10.207802   9.570815
# 7            Age                  Adult  51.314406  20.670798  59.914163
# 8            Age          Age not known   0.026288   0.109369   0.042918
# 9            Age                    Kid  12.723449  10.754648  10.729614
# 10           Age                    Old  18.533123  23.550857       20.0
# 11           Age                  Youth  17.402734  44.914327   9.313305
# 12         03.TM                    Hot  14.839642  22.748815  51.030043
# 13         03.TM                    Low   21.37224  20.087495  23.476395
# 14         03.TM                   Mild  40.431125  18.045935  11.502146
# 15         03.TM               Very low  23.356993  39.117754  13.991416
# 16        06.HRM          High humidity  53.575184  18.410499  16.824034
# 17        06.HRM           Low humidity   9.187697   14.61903  56.609442
# 18        06.HRM      Moderate humidity  16.863828   53.99198  18.712446
# 19        06.HRM              Very high  20.373291  12.978491   7.854077
# 20      10.VVM10             High speed  17.626183  17.207437  66.824034
# 21      10.VVM10              Low speed  58.740799  23.587313  14.892704
# 22      10.VVM10         Moderate speed  23.633018   59.20525  18.283262
# 23       Quarter                      1  16.876972  24.899745  42.317597
# 24       Quarter                      2  21.832282  44.877871  18.755365
# 25       Quarter                      3   22.69979  18.993802  30.214592
# 26       Quarter                      4  38.590957  11.228582   8.712446
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 40448.0
#                            0          1          2   VARIABLE
# Afternoon          65.360904   27.58989  32.694151  Day_shift
# Morning            20.986386  64.578142   64.42953  Day_shift
# Night               13.65271   7.831969   2.876318  Day_shift
# Men                76.059594  78.070488  33.652924     Gender
# Not known           0.025687     0.0356        0.0     Gender
# Women              23.914719  21.893912  66.347076     Gender
# Adult              52.298998  19.437522   59.87536        Age
# Age not known       0.038531     0.1068        0.0        Age
# Kid                 12.53532  11.178355  10.690316        Age
# Old                18.597483  25.596298  17.018217        Age
# Youth              16.529669  43.681025  12.416107        Age
# Hot                16.478294  24.457102  46.596357      03.TM
# Low                21.281788  20.220719  23.921381      03.TM
# Mild               39.365528  17.301531  13.806328      03.TM
# Very low            22.87439  38.020648  15.675935      03.TM
# High humidity      50.963267  18.547526  23.202301     06.HRM
# Low humidity       10.788595  17.871129  51.629914     06.HRM
# Moderate humidity  17.852556  51.121396  17.929051     06.HRM
# Very high          20.395582   12.45995   7.238734     06.HRM
# High speed         19.188287  20.363119  62.511985   10.VVM10
# Low speed          56.832777  22.285511  19.750719   10.VVM10
# Moderate speed     23.978937  57.351371  17.737296   10.VVM10
# 1                  17.454405  25.347099  42.281879    Quarter
# 2                  21.551503   45.03382  18.504314    Quarter
# 3                  23.079887  18.832325  30.009588    Quarter
# 4                  37.914205  10.786757   9.204219    Quarter
# 1
#      VARIABLE              value          0          1          2
# 0   Day_shift          Afternoon  65.360904   27.58989  32.694151
# 1   Day_shift            Morning  20.986386  64.578142   64.42953
# 2   Day_shift              Night   13.65271   7.831969   2.876318
# 3      Gender                Men  76.059594  78.070488  33.652924
# 4      Gender          Not known   0.025687     0.0356        0.0
# 5      Gender              Women  23.914719  21.893912  66.347076
# 6         Age              Adult  52.298998  19.437522   59.87536
# 7         Age      Age not known   0.038531     0.1068        0.0
# 8         Age                Kid   12.53532  11.178355  10.690316
# 9         Age                Old  18.597483  25.596298  17.018217
# 10        Age              Youth  16.529669  43.681025  12.416107
# 11      03.TM                Hot  16.478294  24.457102  46.596357
# 12      03.TM                Low  21.281788  20.220719  23.921381
# 13      03.TM               Mild  39.365528  17.301531  13.806328
# 14      03.TM           Very low   22.87439  38.020648  15.675935
# 15     06.HRM      High humidity  50.963267  18.547526  23.202301
# 16     06.HRM       Low humidity  10.788595  17.871129  51.629914
# 17     06.HRM  Moderate humidity  17.852556  51.121396  17.929051
# 18     06.HRM          Very high  20.395582   12.45995   7.238734
# 19   10.VVM10         High speed  19.188287  20.363119  62.511985
# 20   10.VVM10          Low speed  56.832777  22.285511  19.750719
# 21   10.VVM10     Moderate speed  23.978937  57.351371  17.737296
# 22    Quarter                  1  17.454405  25.347099  42.281879
# 23    Quarter                  2  21.551503   45.03382  18.504314
# 24    Quarter                  3  23.079887  18.832325  30.009588
# 25    Quarter                  4  37.914205  10.786757   9.204219
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 39250.0
#                                0          1          2      VARIABLE
# Car                    13.312223  14.509481  13.050847  Vehicle_type
# Motorcycle             64.395187  61.376752   64.70339  Vehicle_type
# Other                  13.210893  13.891179  13.474576  Vehicle_type
# Vehicle without motor   9.081697  10.222589   8.771186  Vehicle_type
# Men                    76.757441  31.286068  84.661017        Gender
# Not known               0.025332    0.04122        0.0        Gender
# Women                  23.217226  68.672712  15.338983        Gender
# Adult                  58.226726  26.339654  26.737288           Age
# Age not known           0.025332    0.08244   0.084746           Age
# Kid                     11.60228  12.283594  12.669492           Age
# Old                    13.882204  14.509481  45.508475           Age
# Youth                  16.263458  46.784831       15.0           Age
# Hot                    11.792274  19.538335  65.127119         03.TM
# Low                     23.30589   21.55812   15.29661         03.TM
# Mild                   39.974668  16.446826  12.033898         03.TM
# Very low               24.927169  42.456719   7.542373         03.TM
# High humidity           50.69031  18.219291  22.415254        06.HRM
# Low humidity           16.212793  21.846661  25.805085        06.HRM
# Moderate humidity      13.780874  43.528442  44.745763        06.HRM
# Very high              19.316023  16.405606   7.033898        06.HRM
# High speed             16.985434  19.826876   65.59322      10.VVM10
# Low speed              58.505383  22.464963  12.669492      10.VVM10
# Moderate speed         24.509183  57.708162  21.737288      10.VVM10
# 1                      23.242559  29.802143  16.737288       Quarter
# 2                      22.571248  45.589448  18.686441       Quarter
# 3                       16.08613  12.901896  58.008475       Quarter
# 4                      38.100063  11.706513   6.567797       Quarter
# 1
#         VARIABLE                  value          0          1          2
# 0   Vehicle_type                    Car  13.312223  14.509481  13.050847
# 1   Vehicle_type             Motorcycle  64.395187  61.376752   64.70339
# 2   Vehicle_type                  Other  13.210893  13.891179  13.474576
# 3   Vehicle_type  Vehicle without motor   9.081697  10.222589   8.771186
# 4         Gender                    Men  76.757441  31.286068  84.661017
# 5         Gender              Not known   0.025332    0.04122        0.0
# 6         Gender                  Women  23.217226  68.672712  15.338983
# 7            Age                  Adult  58.226726  26.339654  26.737288
# 8            Age          Age not known   0.025332    0.08244   0.084746
# 9            Age                    Kid   11.60228  12.283594  12.669492
# 10           Age                    Old  13.882204  14.509481  45.508475
# 11           Age                  Youth  16.263458  46.784831       15.0
# 12         03.TM                    Hot  11.792274  19.538335  65.127119
# 13         03.TM                    Low   23.30589   21.55812   15.29661
# 14         03.TM                   Mild  39.974668  16.446826  12.033898
# 15         03.TM               Very low  24.927169  42.456719   7.542373
# 16        06.HRM          High humidity   50.69031  18.219291  22.415254
# 17        06.HRM           Low humidity  16.212793  21.846661  25.805085
# 18        06.HRM      Moderate humidity  13.780874  43.528442  44.745763
# 19        06.HRM              Very high  19.316023  16.405606   7.033898
# 20      10.VVM10             High speed  16.985434  19.826876   65.59322
# 21      10.VVM10              Low speed  58.505383  22.464963  12.669492
# 22      10.VVM10         Moderate speed  24.509183  57.708162  21.737288
# 23       Quarter                      1  23.242559  29.802143  16.737288
# 24       Quarter                      2  22.571248  45.589448  18.686441
# 25       Quarter                      3   16.08613  12.901896  58.008475
# 26       Quarter                      4  38.100063  11.706513   6.567797
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 44975.0
#                                0          1          2      VARIABLE
# Afternoon              63.471116  30.700256   31.59948     Day_shift
# Morning                23.169821  62.382579  63.719116     Day_shift
# Night                  13.359064   6.917165   4.681404     Day_shift
# Car                    13.234562  14.688301  13.177287  Vehicle_type
# Motorcycle             64.666335  60.162254  64.889467  Vehicle_type
# Other                  13.271912  13.962425  13.220633  Vehicle_type
# Vehicle without motor   8.827191   11.18702   8.712614  Vehicle_type
# Men                    75.846614  32.707088  84.915475        Gender
# Not known                 0.0249   0.042699        0.0        Gender
# Women                  24.128486  67.250213  15.084525        Gender
# Adult                  56.598606  27.882152  28.955353           Age
# Age not known             0.0249   0.085397   0.086693           Age
# Kid                    11.815239  11.784799  12.483745           Age
# Old                    14.006474  16.310845  43.996532           Age
# Youth                  17.554781  43.936806  14.477677           Age
# Hot                    13.022908  21.221178  60.641526         03.TM
# Low                    23.169821  20.751494  16.341569         03.TM
# Mild                   38.383964  17.335611  15.171218         03.TM
# Very low               25.423307  40.691716   7.845687         03.TM
# High humidity          49.414841  20.111016  23.103598        06.HRM
# Low humidity           11.342131  17.762596    47.3342        06.HRM
# Moderate humidity      18.949203  48.590948  23.407022        06.HRM
# Very high              20.293825   13.53544    6.15518        06.HRM
# High speed             18.289343  19.171648  62.938882      10.VVM10
# Low speed              56.997012  24.081981  13.914174      10.VVM10
# Moderate speed         24.713645  56.746371  23.146944      10.VVM10
# 1                      22.783865  29.504697  18.725618       Quarter
# 2                      23.406375  42.485056  19.679237       Quarter
# 3                      17.405378  14.432109  52.709146       Quarter
# 4                      36.404382  13.578138   8.885999       Quarter
# 1
#         VARIABLE                  value          0          1          2
# 0      Day_shift              Afternoon  63.471116  30.700256   31.59948
# 1      Day_shift                Morning  23.169821  62.382579  63.719116
# 2      Day_shift                  Night  13.359064   6.917165   4.681404
# 3   Vehicle_type                    Car  13.234562  14.688301  13.177287
# 4   Vehicle_type             Motorcycle  64.666335  60.162254  64.889467
# 5   Vehicle_type                  Other  13.271912  13.962425  13.220633
# 6   Vehicle_type  Vehicle without motor   8.827191   11.18702   8.712614
# 7         Gender                    Men  75.846614  32.707088  84.915475
# 8         Gender              Not known     0.0249   0.042699        0.0
# 9         Gender                  Women  24.128486  67.250213  15.084525
# 10           Age                  Adult  56.598606  27.882152  28.955353
# 11           Age          Age not known     0.0249   0.085397   0.086693
# 12           Age                    Kid  11.815239  11.784799  12.483745
# 13           Age                    Old  14.006474  16.310845  43.996532
# 14           Age                  Youth  17.554781  43.936806  14.477677
# 15         03.TM                    Hot  13.022908  21.221178  60.641526
# 16         03.TM                    Low  23.169821  20.751494  16.341569
# 17         03.TM                   Mild  38.383964  17.335611  15.171218
# 18         03.TM               Very low  25.423307  40.691716   7.845687
# 19        06.HRM          High humidity  49.414841  20.111016  23.103598
# 20        06.HRM           Low humidity  11.342131  17.762596    47.3342
# 21        06.HRM      Moderate humidity  18.949203  48.590948  23.407022
# 22        06.HRM              Very high  20.293825   13.53544    6.15518
# 23      10.VVM10             High speed  18.289343  19.171648  62.938882
# 24      10.VVM10              Low speed  56.997012  24.081981  13.914174
# 25      10.VVM10         Moderate speed  24.713645  56.746371  23.146944
# 26       Quarter                      1  22.783865  29.504697  18.725618
# 27       Quarter                      2  23.406375  42.485056  19.679237
# 28       Quarter                      3  17.405378  14.432109  52.709146
# 29       Quarter                      4  36.404382  13.578138   8.885999
